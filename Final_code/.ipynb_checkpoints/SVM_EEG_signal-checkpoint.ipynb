# %%
import scipy.io as sio
import matplotlib.pyplot as plt
import numpy as np
from sklearn import linear_model, neighbors,datasets
from lib.helpers import *
from sklearn import svm
from lib.cross_validations_lib import *
#import peakutils
import scipy.signal as signal
import numpy as np
from sklearn.decomposition import PCA
from sklearn.cluster import MeanShift, estimate_bandwidth
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-73445db6216c> in <module>()
#       3 import numpy as np
#       4 from sklearn import linear_model, neighbors,datasets
# ----> 5 from lib.helpers import *
#       6 from sklearn import svm
#       7 from lib.cross_validations_lib import *
#
# ImportError: No module named 'lib'

# %%
def feature_extraction(signal,feature_dictionary,f_peak):
    feature=[]
    
    if(feature_dictionary["fft_peak_frequencies"]==1):
        feature=np.concatenate((feature,f_peak.reshape(f_peak.shape[1])), axis=0);
        
    if(feature_dictionary["mean"]==1):
        mean=np.mean(signal);
        feature=np.concatenate((feature,[mean]), axis=0)
    
    if(feature_dictionary["variance"]==1):
        variance=np.var(signal)
        feature=np.concatenate((feature,[variance]), axis=0)
    #crest factor 
    if(feature_dictionary["crest_factor"]==1):
        crest_factor=np.sum(np.power(signal,2))/signal.size
        feature=np.concatenate((feature,[crest_factor]), axis=0)
    
    return np.asarray(feature)
#.reshape([feature.size,1])


def split_matrix_two_blocks(y, percentage1, percentage2, seed):
    """Build k indices for k-fold."""
    if(percentage1+percentage2==1):
        num_row = len(y)
        print(num_row)
        interval_1 = int(percentage1*num_row);
        
        np.random.seed(seed)
        indices = np.random.permutation(num_row);
        first_indices = indices[0:interval_1];
        second_indices = indices[interval_1:num_row];
        return [np.array(first_indices),np.array(second_indices)]
    else:
        print('>>>>>>>>>>>ERROR:Not valid splitting percentage')

# %%
def export_signals(channels):
    time_instances=[];
    dim=channels.shape;
    #find the length min of the signal in the specified temporal instance
    # for NIRS signal ==80 
    length_min=len(channels[0,1]);
    for i in range (0,dim[1]):
        single_measurement=channels[0,i];
        single_length=single_measurement.shape[0]
        if(single_length<length_min):
                length_min=single_length;
    #export the signals
    for i in range (0,dim[1]):
        single_measurement=channels[0,i];
        dim1=single_measurement.shape;
        time_instance=[];
        for j  in range (0,dim1[1]):
            if(len(single_measurement[:,j])>length_min):
                single_signal=single_measurement[:,j][0:length_min]
            else:
                single_signal=single_measurement[:,j]
            #put in a list 
            time_instance.append(np.asarray(single_signal).reshape(len(single_signal),1).T);
       # create the matrix of the signals per a single time instance 
        time_instance=np.concatenate(time_instance);
        time_instances.append(time_instance);   
    return time_instances;


def get_feature_matrix_and_labels(channel_structure,label,features_extracted,connectivity_feature):
    list_train=[]
    list_labels=[]
    cont=0;
    index_connectivity=0;
    list_row=[]
    
    for time_instance in channel_structure:
        dim1=time_instance.shape
        #indipendent_components=extract_ICs(time_instance,n_ICA_components);
        for j  in range (0,dim1[0]):
           
            features=features_extracted[cont,:];
            list_row.append(features);
            cont=cont+1;
        """feature_dictionary["fft_max_frequencies"]=0;
        for single_component in indipendent_components:
            features=feature_extraction(single_component,feature_dictionary,features_extracted)
            list_row.append(features);"""
        list_row.append(connectivity_feature[index_connectivity,:]);
        index_connectivity=index_connectivity+1;
        labels=get_labels(1,label);
        feature_row=np.concatenate(list_row);
        list_train.append(feature_row.reshape(len(feature_row),1).T)
        list_labels.append(labels);
        list_row=[]
        
    train_TX=np.concatenate(list_train)
    labels=np.concatenate(list_labels,axis=0)
    
    return train_TX,labels.T.reshape(labels.size)


def get_labels(number, string):
    if(string=="No"):
        return np.zeros(number)    
    if(string=="Yes"):
        return np.ones(number)
def select_features(weights,matrix,th):
    cont=0;
    i=0;
    while(cont<len(weights)):
        if(weights[cont]<th):

            mask = np.ones(matrix.shape[1], dtype=bool)
            mask[i] = False
            matrix=matrix[:,mask]
        else:
            i=i+1;
        cont=cont+1;
    return matrix

# %% [markdown]
# # EEG

# %%
yes_EEG_contents = sio.loadmat('EEGyes.mat')
no_EEG_contents = sio.loadmat('EEGno.mat')


channels_no_EEG=no_EEG_contents["EEGno"]
channels_yes_EEG=yes_EEG_contents["EEGyes"]

"""pick_yes_EEG_contents = sio.loadmat('pick_EEG_yes_signal.mat')
pick_no_EEG_contents = sio.loadmat('pick_EEG_no_signal.mat')"""
features_extracted_yes=sio.loadmat('FeaturesYes.mat')['FeaturesYes']
features_extracted_no=sio.loadmat('FeaturesNO.mat')['FeaturesNo']
connectivity_feature_yes=sio.loadmat('ConnectivityFeaturesYes.mat')['ConnectivityFeaturesYes']
connectivity_feature_no=sio.loadmat('ConnectivityFeaturesNo.mat')['ConnectivityFeaturesNo']


# select which feature select
feature_dictionary = {
        "fft_peak_frequencies" : 0, 
         "mean" : 0, 
         "variance" : 0,
         "crest_factor" : 0
         }




channels_structure_yes_EEG=export_signals(channels_yes_EEG)
channels_structure_no_EEG=export_signals(channels_no_EEG)


"""features_extracted={
    "peak_signal" : pick_yes_EEG_contents,
        }
"""

train_TX_yes_EEG,EEG_yes_labels=get_feature_matrix_and_labels(channels_structure_yes_EEG,"Yes",features_extracted_yes,connectivity_feature_yes);

"""features_extracted={
    "peak_signal" : pick_no_EEG_contents,
}"""


train_TX_no_EEG,EEG_no_labels=get_feature_matrix_and_labels(channels_structure_no_EEG,"No",features_extracted_no,connectivity_feature_no);



train_TX=np.concatenate((train_TX_yes_EEG,train_TX_no_EEG,),axis=0)

print(train_TX.shape)
labels=np.concatenate((EEG_yes_labels,EEG_no_labels),axis=0)

print(train_TX)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-a3528aa09065> in <module>()
#       8 """pick_yes_EEG_contents = sio.loadmat('pick_EEG_yes_signal.mat')
#       9 pick_no_EEG_contents = sio.loadmat('pick_EEG_no_signal.mat')"""
# ---> 10 features_extracted_yes=sio.loadmat('FeaturesYes.mat')['FeaturesYes']
#      11 features_extracted_no=sio.loadmat('FeaturesNO.mat')['FeaturesNo']
#      12 connectivity_feature_yes=sio.loadmat('ConnectivityFeaturesYes.mat')['ConnectivityFeaturesYes']
#
# ~/anaconda/lib/python3.5/site-packages/scipy/io/matlab/mio.py in loadmat(file_name, mdict, appendmat, **kwargs)
#     139     """
#     140     variable_names = kwargs.pop('variable_names', None)
# --> 141     MR, file_opened = mat_reader_factory(file_name, appendmat, **kwargs)
#     142     matfile_dict = MR.get_variables(variable_names)
#     143     if mdict is not None:
#
# ~/anaconda/lib/python3.5/site-packages/scipy/io/matlab/mio.py in mat_reader_factory(file_name, appendmat, **kwargs)
#      62
#      63     """
# ---> 64     byte_stream, file_opened = _open_file(file_name, appendmat)
#      65     mjv, mnv = get_matfile_version(byte_stream)
#      66     if mjv == 0:
#
# TypeError: 'NoneType' object is not iterable

# %%
# REGULARIZATION
degrees = np.array([1])
lambdas = np.logspace(-8,-2,6)
k_fold=10
seed = 2
max_iters = 5000
print(train_TX.shape)

best_deg,best_lambda, best_accuracy_test, corresponding_accuracy_train = \
        cross_validation_logistic_regularized(labels,train_TX, degrees, lambdas, k_fold, seed, max_iters)
# Out:
# (60, 386)
# --- Fold 0 ---
# ++ Degree 1 ++
# >> Lambda 1e-08 <<
# 1.0
# >> Lambda 1.58489319246e-07 <<
# 1.0
# >> Lambda 2.51188643151e-06 <<
# 1.0
# >> Lambda 3.98107170553e-05 <<
# 1.0
# >> Lambda 0.00063095734448 <<
# 1.0
# >> Lambda 0.01 <<
# 0.833333333333
# --- Fold 1 ---
# ++ Degree 1 ++
# >> Lambda 1e-08 <<
# 0.833333333333
# >> Lambda 1.58489319246e-07 <<
# 0.833333333333
# >> Lambda 2.51188643151e-06 <<
# 0.666666666667
# >> Lambda 3.98107170553e-05 <<
# 0.666666666667
# >> Lambda 0.00063095734448 <<
# 0.5
# >> Lambda 0.01 <<
# 0.666666666667
# --- Fold 2 ---
# ++ Degree 1 ++
# >> Lambda 1e-08 <<
# 1.0
# >> Lambda 1.58489319246e-07 <<
# 1.0
# >> Lambda 2.51188643151e-06 <<
# 1.0
# >> Lambda 3.98107170553e-05 <<
# 1.0
# >> Lambda 0.00063095734448 <<
# 0.833333333333
# >> Lambda 0.01 <<
# 0.5
# --- Fold 3 ---
# ++ Degree 1 ++
# >> Lambda 1e-08 <<
# 1.0
# >> Lambda 1.58489319246e-07 <<
# 1.0
# >> Lambda 2.51188643151e-06 <<
# 1.0
# >> Lambda 3.98107170553e-05 <<
# 1.0
# >> Lambda 0.00063095734448 <<
# 1.0
# >> Lambda 0.01 <<
# 1.0
# --- Fold 4 ---
# ++ Degree 1 ++
# >> Lambda 1e-08 <<
# 1.0
# >> Lambda 1.58489319246e-07 <<
# 1.0
# >> Lambda 2.51188643151e-06 <<
# 1.0
# >> Lambda 3.98107170553e-05 <<
# 1.0
# >> Lambda 0.00063095734448 <<
# 1.0
# >> Lambda 0.01 <<
# 0.833333333333
# --- Fold 5 ---
# ++ Degree 1 ++
# >> Lambda 1e-08 <<
# 1.0
# >> Lambda 1.58489319246e-07 <<
# 1.0
# >> Lambda 2.51188643151e-06 <<
# 1.0
# >> Lambda 3.98107170553e-05 <<
# 1.0
# >> Lambda 0.00063095734448 <<
# 1.0
# >> Lambda 0.01 <<
# 1.0
# --- Fold 6 ---
# ++ Degree 1 ++
# >> Lambda 1e-08 <<
# 1.0
# >> Lambda 1.58489319246e-07 <<
# 1.0
# >> Lambda 2.51188643151e-06 <<
# 1.0
# >> Lambda 3.98107170553e-05 <<
# 0.833333333333
# >> Lambda 0.00063095734448 <<
# 0.833333333333
# >> Lambda 0.01 <<
# 0.833333333333
# --- Fold 7 ---
# ++ Degree 1 ++
# >> Lambda 1e-08 <<
# 0.833333333333
# >> Lambda 1.58489319246e-07 <<
# 0.833333333333
# >> Lambda 2.51188643151e-06 <<
# 1.0
# >> Lambda 3.98107170553e-05 <<
# 0.833333333333
# >> Lambda 0.00063095734448 <<
# 1.0
# >> Lambda 0.01 <<
# 1.0
# --- Fold 8 ---
# ++ Degree 1 ++
# >> Lambda 1e-08 <<
# 0.833333333333
# >> Lambda 1.58489319246e-07 <<
# 0.833333333333
# >> Lambda 2.51188643151e-06 <<
# 0.833333333333
# >> Lambda 3.98107170553e-05 <<
# 0.833333333333
# >> Lambda 0.00063095734448 <<
# 0.833333333333
# >> Lambda 0.01 <<
# 1.0
# --- Fold 9 ---
# ++ Degree 1 ++
# >> Lambda 1e-08 <<
# 0.666666666667
# >> Lambda 1.58489319246e-07 <<
# 0.666666666667
# >> Lambda 2.51188643151e-06 <<
# 0.5
# >> Lambda 3.98107170553e-05 <<
# 0.833333333333
# >> Lambda 0.00063095734448 <<
# 0.833333333333
# >> Lambda 0.01 <<
# 0.833333333333
# Best accuracy test = 0.916666666667 with degree = 1 lambda= 1e-08
# Corresponding accuracy train = 1.0

# %%
#LOGISTIC 

max_iters = 100000
[i1,i2]=split_matrix_two_blocks(train_TX,0.7,0.3,2)

# TRAIN SET 

train=train_TX[i1,:]
labels_train=labels[i1]

# TEST SET
test= train_TX[i2,:]
labels_test=labels[i2]


logreg = linear_model.LogisticRegression(penalty='l1',C=1/best_lambda,max_iter=max_iters)


logreg.fit(train, labels_train)  
predicted_labels= logreg.predict(test)


logistic_accuracy=get_accuracy(predicted_labels, labels_test)
print(logistic_accuracy)

plt.plot(logreg.coef_[0],'bo')
plt.show()
print(logreg.coef_[0])
th=np.mean(np.abs(logreg.coef_[0]/10))

train_TX=select_features(logreg.coef_[0],train_TX,th)

print(train_TX.shape)
# Out:
# 60
# 0.888888888889
# [  2.09849268e-03   6.53124710e-03  -5.80343086e-03   6.96160726e-02
#   -3.31893621e-03   1.20423388e-02   4.83168697e-03   5.59268430e-02
#   -1.46117298e-03   1.96901722e-03  -1.73924452e-02   1.24978962e-01
#    9.22985800e-04  -3.11308166e-03   1.98011596e-02   5.83979979e-02
#    7.85652052e-03   1.05753300e-02   1.17264898e-01   5.53515348e-02
#    1.80398036e-02  -1.48163247e-03   1.98015640e-01   1.51238500e-01
#    4.65944305e-01   4.51697497e-01   2.46890686e+00  -1.55506226e-01
#    1.74206478e+00  -3.26043450e+00   1.55696213e+00   7.53687609e-01
#   -2.57339639e-03   1.15325622e-02   7.95196676e-03   2.51896865e-01
#   -1.56596064e-02   1.12422365e-02  -7.44996747e-03   3.85021797e-01
#   -5.62903366e+00   5.41955487e+00   2.70117131e+01  -7.39628790e+00
#   -1.28050160e-02  -6.36370972e-02  -1.41245974e-02  -3.86711419e-02
#   -1.12373855e-03   4.59082165e-03  -2.91273835e-02   1.24289925e-01
#   -7.28689007e-04   1.80415320e-03   1.44846125e-02   1.31985121e-01
#   -2.95494599e-03   6.79310130e-03  -7.90577316e-02   1.56045399e-01
#   -2.72126183e-03   1.98884674e+00  -1.12639124e+01   3.97105591e+01
#   -6.14396801e-01   3.58135353e-01   5.70850587e-01   5.43804793e-01
#    1.30977277e-01   1.27313784e-01   2.37738741e-01  -3.52062767e-03
#   -3.28656056e-02  -6.32351395e-03   1.49056459e-02  -7.50024073e-03
#   -2.37264788e-02  -4.11512615e-02   1.05612303e-02  -1.72024125e-02
#   -1.97680870e-02   4.25713249e-03   1.78987385e-02   3.10948258e-02
#   -3.54979462e-02   1.51719170e-02   7.44737710e-03  -1.94534249e-02
#   -2.21692393e-02  -2.77588206e-02   2.03227756e-04  -1.07475542e-01
#   -1.27627257e-01  -2.16483661e-01   2.55191816e-02  -1.46162147e-01
#   -3.30578307e-01  -5.56857991e-01  -9.29439079e-01  -2.74228337e+00
#   -2.29546326e+00  -4.03795423e+00   7.16730062e-02   2.05752214e+00
#   -1.55078714e+00  -2.87892756e+00   6.86250342e-03   2.58821729e-02
#   -5.03039387e-02   2.44084939e-02   4.51590112e-02   1.22362170e-01
#    1.57177245e-02  -1.73248508e-01  -1.65923671e+00  -6.79859019e+01
#   -2.79901462e+01   6.96712151e-03  -1.41356003e-01  -9.30544521e-02
#   -1.36676017e-01  -4.04412301e-02   2.77948514e-03   1.09653776e-02
#   -4.50654540e-02  -7.72370503e-02   1.72250446e-03  -4.31072240e-03
#   -6.50811644e-02  -5.05892331e-02   5.29671592e-04  -2.49692040e-03
#   -8.37479666e-02  -7.36401936e-02   3.11969435e-01  -2.19236850e+00
#   -2.66181401e+01  -4.24123193e+01  -9.34833729e-02  -2.03930406e-01
#   -3.72672058e-02   1.84788064e-01  -2.00181722e-01  -1.90722089e-01
#    4.15333277e-02   5.99243897e-02   2.59186041e-02  -2.30877497e-02
#   -2.12018995e-03  -1.03155437e-02  -1.34182544e-03   2.69107237e-02
#    1.40515033e-03  -1.70195415e-02  -9.07550025e-03   2.55688086e-03
#   -7.55190494e-03   2.58915469e-02  -4.91785324e-02   4.42971985e-02
#    5.49079236e-03  -5.67241645e-03   6.61779658e-03   1.76125574e-03
#    2.50108516e-02  -9.57549077e-02   4.73601824e-02  -3.74963616e-02
#    4.95867649e-02  -2.14857110e-01   4.86032283e-04  -2.46608015e-01
#    2.45061954e+00  -2.02320545e+00   8.37833535e-01  -2.94359988e+00
#    8.45856083e-01   1.09174689e+00  -1.58198066e+00   2.08996211e+00
#    9.29454819e-05  -5.92470179e-02   3.22137898e-02   6.48837823e-02
#   -4.46533489e-03  -1.07206604e-01   2.16356496e-02   4.54165891e-02
#   -4.19754779e+00   4.81783091e+01   3.37268470e+01  -1.97442167e+01
#    2.10571850e-01  -3.01217964e-02  -2.09778366e-02  -6.85654974e-02
#   -3.95620721e-04  -2.25197106e-02   2.04092879e-02   3.46132876e-02
#    1.69619314e-03  -3.89766629e-02  -3.07526143e-02  -3.09086246e-02
#   -1.17940878e-03  -2.40002335e-02   2.12660162e-02  -3.81896363e-02
#    1.32182818e-01  -1.25830021e+00   1.18487974e+01   7.81925820e+00
#    1.17322824e+00   2.41926047e-01  -3.19964479e-01   3.18443029e-01
#    7.32297185e-01  -3.15913434e-03  -1.49324897e-01   1.03043528e-01
#    8.22322885e-02   2.06736432e-02   3.98452061e-03  -3.01085525e-02
#   -3.47338271e-02   2.01089443e-02   5.96855753e-03  -2.33793772e-02
#   -3.07856451e-02  -4.76431172e-02   4.60735845e-03  -1.45567353e-02
#   -8.90893054e-03  -5.70032776e-03   2.23112109e-03  -2.56243687e-02
#   -2.68404240e-02   2.87999491e-02   1.26263979e-02  -2.63605139e-02
#   -1.77063171e-01   1.07654815e-01   3.43791456e-02   1.98995785e-02
#   -3.61139822e-01   1.36162712e-01   1.03372588e+00   1.42976739e+00
#   -3.64524533e+00   3.36243700e+00  -3.13959365e-01   8.98961079e-01
#    1.04692810e+00   3.35441043e+00   1.98029991e-03  -2.90072668e-02
#   -1.75891194e-01   5.79125674e-02   1.52327582e-02  -1.72414693e-02
#   -1.05672272e-01   9.79439535e-02  -9.59674882e+00   4.13436837e+01
#    2.83357209e+01  -2.51936746e+01   9.58308158e-02   6.10542728e-02
#   -3.40218816e-02   8.66006330e-02   1.62334393e-03  -1.76424411e-02
#   -5.37431663e-02   2.49111169e-02   2.38304614e-03  -1.67063811e-02
#   -8.38050644e-02  -6.82723878e-04   1.46373393e-03  -2.63377069e-02
#   -8.25715802e-02   4.49705334e-03   1.39433688e-01  -3.81551695e+00
#   -1.58535921e+01   8.93098292e+00   1.98601963e-01  -2.18313410e-01
#    6.23496726e-01   1.08447022e-02   1.64993316e-01  -2.14793462e-01
#    2.52130198e-01   2.28159157e-01  -8.10721204e-02  -5.87095136e-02
#   -5.83378270e-03  -4.84613993e-03   5.04405869e-02   2.09369883e-02
#   -9.33992014e-03   5.54989980e-03   3.35470017e-02   2.85755825e-02
#   -3.45346484e-02   1.82205782e-02   1.82314248e-02   9.04664536e-02
#    8.42993598e-04  -7.09422412e-03   2.00615436e-02   2.80237803e-02
#    2.00168828e-02  -3.82630723e-03   8.60995213e-02  -1.26588681e-01
#    2.87555424e-02  -2.75678927e-02   3.24517883e-01  -2.47182179e-01
#    2.97769477e+00  -1.47924267e+00   2.53227434e+00  -1.75107499e+00
#   -2.86952635e+00   9.14473878e-01   1.01921921e+00   2.99639080e+00
#   -4.48290853e-03   2.60846410e-02   7.04434456e-02  -1.75582242e-02
#   -1.77131510e-02   6.67746299e-02   6.59007994e-02   1.41719725e-02
#   -4.04694812e-02  -1.80281206e+01   1.36418797e+01   1.30462488e+01
#    1.13411901e-01   7.59953766e-02   5.55056100e-02  -3.34134516e-02
#   -1.59926208e-03   1.44964704e-02   3.24485448e-02  -2.67642610e-03
#   -6.73730704e-04  -1.91168394e-03   6.56209288e-02  -2.15935544e-02
#   -3.44751793e-03   9.52520698e-03   1.34799516e-01   3.59885165e-02
#   -4.72741575e-01   3.51151044e+00   3.80236082e+01   2.42721984e+01
#   -2.34042921e-01  -2.98093175e-02  -2.74995054e-02  -1.14854808e-03
#    2.47166593e-02  -1.74810847e-01  -1.35747059e-01   2.80169710e-01
#    5.61496387e-02   6.32832427e-02   1.25677250e+00  -3.42598782e-01
#   -1.40518865e+00   3.19314479e+00  -4.25395788e-01   1.96834163e-01
#   -2.90855943e-01   1.63448842e+00   8.23017421e-02   1.22442086e-01
#   -3.46493152e-01  -2.41245401e-01   4.09520018e-01   2.57742129e-01
#   -1.22294179e-01   5.39725955e-01]
# (60, 65)

# %%
C_parameters= np.linspace(0.1,5,10)
k_fold=30 # number of k sub-folders to divide the set
seed = 2
max_iters = 100
kernel_types=['linear', 'rbf', 'sigmoid']
print(train_TX.shape)

best_C, best_kernel_type ,best_accuracy_test, corresponding_accuracy_train = \
        cross_validation_SVM(labels,train_TX, C_parameters, kernel_types, k_fold, seed, max_iters)
# Out:
# (60, 65)
# --- Fold 0 ---
# >> Penalty parameter C 0.1 <<
# >> Type of Kernel  linear <<
# 0.5 0.793103448276
# >> Type of Kernel  rbf <<
# 1.0 0.586206896552
# >> Type of Kernel  sigmoid <<
# 1.0 0.586206896552
# >> Penalty parameter C 0.644444444444 <<
# >> Type of Kernel  linear <<
# 0.5 0.896551724138
# >> Type of Kernel  rbf <<
# 1.0 0.603448275862
# >> Type of Kernel  sigmoid <<
# 1.0 0.586206896552
# >> Penalty parameter C 1.18888888889 <<
# >> Type of Kernel  linear <<
# 0.5 0.931034482759
# >> Type of Kernel  rbf <<
# 1.0 0.689655172414
# >> Type of Kernel  sigmoid <<
# 1.0 0.586206896552
# >> Penalty parameter C 1.73333333333 <<
# >> Type of Kernel  linear <<
# 0.5 0.948275862069
# >> Type of Kernel  rbf <<
# 1.0 0.724137931034
# >> Type of Kernel  sigmoid <<
# 0.5 0.655172413793
# >> Penalty parameter C 2.27777777778 <<
# >> Type of Kernel  linear <<
# 0.5 0.948275862069
# >> Type of Kernel  rbf <<
# 0.5 0.793103448276
# >> Type of Kernel  sigmoid <<
# 1.0 0.603448275862
# >> Penalty parameter C 2.82222222222 <<
# >> Type of Kernel  linear <<
# 0.5 0.948275862069
# >> Type of Kernel  rbf <<
# 0.5 0.810344827586
# >> Type of Kernel  sigmoid <<
# 1.0 0.672413793103
# >> Penalty parameter C 3.36666666667 <<
# >> Type of Kernel  linear <<
# 0.5 0.948275862069
# >> Type of Kernel  rbf <<
# 0.5 0.844827586207
# >> Type of Kernel  sigmoid <<
# 0.5 0.655172413793
# >> Penalty parameter C 3.91111111111 <<
# >> Type of Kernel  linear <<
# 0.5 0.948275862069
# >> Type of Kernel  rbf <<
# 0.5 0.862068965517
# >> Type of Kernel  sigmoid <<
# 0.5 0.672413793103
# >> Penalty parameter C 4.45555555556 <<
# >> Type of Kernel  linear <<
# 0.5 0.98275862069
# >> Type of Kernel  rbf <<
# 0.5 0.862068965517
# >> Type of Kernel  sigmoid <<
# 0.5 0.672413793103
# >> Penalty parameter C 5.0 <<
# >> Type of Kernel  linear <<
# 0.5 0.98275862069
# >> Type of Kernel  rbf <<
# 0.5 0.844827586207
# >> Type of Kernel  sigmoid <<
# 0.5 0.672413793103
# --- Fold 1 ---
# >> Penalty parameter C 0.1 <<
# >> Type of Kernel  linear <<
# 1.0 0.775862068966
# >> Type of Kernel  rbf <<
# 0.0 0.51724137931
# >> Type of Kernel  sigmoid <<
# 0.0 0.51724137931
# >> Penalty parameter C 0.644444444444 <<
# >> Type of Kernel  linear <<
# 1.0 0.879310344828
# >> Type of Kernel  rbf <<
# 1.0 0.689655172414
# >> Type of Kernel  sigmoid <<
# 0.0 0.51724137931
# >> Penalty parameter C 1.18888888889 <<
# >> Type of Kernel  linear <<
# 1.0 0.896551724138
# >> Type of Kernel  rbf <<
# 1.0 0.672413793103
# >> Type of Kernel  sigmoid <<
# 0.0 0.568965517241
# >> Penalty parameter C 1.73333333333 <<
# >> Type of Kernel  linear <<
# 1.0 0.948275862069
# >> Type of Kernel  rbf <<
# 1.0 0.741379310345
# >> Type of Kernel  sigmoid <<
# 1.0 0.706896551724
# >> Penalty parameter C 2.27777777778 <<
# >> Type of Kernel  linear <<
# 1.0 0.931034482759
# >> Type of Kernel  rbf <<
# 1.0 0.758620689655
# >> Type of Kernel  sigmoid <<
# 1.0 0.706896551724
# >> Penalty parameter C 2.82222222222 <<
# >> Type of Kernel  linear <<
# 1.0 0.948275862069
# >> Type of Kernel  rbf <<
# 1.0 0.775862068966
# >> Type of Kernel  sigmoid <<
# 1.0 0.724137931034
# >> Penalty parameter C 3.36666666667 <<
# >> Type of Kernel  linear <<
# 1.0 0.965517241379
# >> Type of Kernel  rbf <<
# 1.0 0.793103448276
# >> Type of Kernel  sigmoid <<
# 1.0 0.724137931034
# >> Penalty parameter C 3.91111111111 <<
# >> Type of Kernel  linear <<
# 1.0 0.965517241379
# >> Type of Kernel  rbf <<
# 1.0 0.810344827586
# >> Type of Kernel  sigmoid <<
# 1.0 0.706896551724
# >> Penalty parameter C 4.45555555556 <<
# >> Type of Kernel  linear <<
# 1.0 0.965517241379
# >> Type of Kernel  rbf <<
# 1.0 0.827586206897
# >> Type of Kernel  sigmoid <<
# 1.0 0.706896551724
# >> Penalty parameter C 5.0 <<
# >> Type of Kernel  linear <<
# 1.0 0.965517241379
# >> Type of Kernel  rbf <<
# 1.0 0.862068965517
# >> Type of Kernel  sigmoid <<
# 1.0 0.689655172414
# --- Fold 2 ---
# >> Penalty parameter C 0.1 <<
# >> Type of Kernel  linear <<
# 0.5 0.758620689655
# >> Type of Kernel  rbf <<
# 0.5 0.603448275862
# >> Type of Kernel  sigmoid <<
# 0.5 0.603448275862
# >> Penalty parameter C 0.644444444444 <<
# >> Type of Kernel  linear <<
# 1.0 0.879310344828
# >> Type of Kernel  rbf <<
# 0.5 0.637931034483
# >> Type of Kernel  sigmoid <<
# 0.5 0.603448275862
# >> Penalty parameter C 1.18888888889 <<
# >> Type of Kernel  linear <<
# 1.0 0.896551724138
# >> Type of Kernel  rbf <<
# 0.0 0.706896551724
# >> Type of Kernel  sigmoid <<
# 0.5 0.603448275862
# >> Penalty parameter C 1.73333333333 <<
# >> Type of Kernel  linear <<
# 1.0 0.948275862069
# >> Type of Kernel  rbf <<
# 0.5 0.706896551724
# >> Type of Kernel  sigmoid <<
# 0.5 0.637931034483
# >> Penalty parameter C 2.27777777778 <<
# >> Type of Kernel  linear <<
# 1.0 0.948275862069
# >> Type of Kernel  rbf <<
# 0.5 0.724137931034
# >> Type of Kernel  sigmoid <<
# 0.5 0.655172413793
# >> Penalty parameter C 2.82222222222 <<
# >> Type of Kernel  linear <<
# 1.0 0.948275862069
# >> Type of Kernel  rbf <<
# 0.5 0.741379310345
# >> Type of Kernel  sigmoid <<
# 0.0 0.672413793103
# >> Penalty parameter C 3.36666666667 <<
# >> Type of Kernel  linear <<
# 1.0 0.948275862069
# >> Type of Kernel  rbf <<
# 0.5 0.758620689655
# >> Type of Kernel  sigmoid <<
# 0.0 0.672413793103
# >> Penalty parameter C 3.91111111111 <<
# >> Type of Kernel  linear <<
# 1.0 0.965517241379
# >> Type of Kernel  rbf <<
# 0.5 0.793103448276
# >> Type of Kernel  sigmoid <<
# 0.0 0.724137931034
# >> Penalty parameter C 4.45555555556 <<
# >> Type of Kernel  linear <<
# 1.0 0.965517241379
# >> Type of Kernel  rbf <<
# 1.0 0.827586206897
# >> Type of Kernel  sigmoid <<
# 0.0 0.724137931034
# >> Penalty parameter C 5.0 <<
# >> Type of Kernel  linear <<
# 1.0 0.98275862069
# >> Type of Kernel  rbf <<
# 1.0 0.862068965517
# >> Type of Kernel  sigmoid <<
# 0.0 0.689655172414
# --- Fold 3 ---
# >> Penalty parameter C 0.1 <<
# >> Type of Kernel  linear <<
# 0.5 0.775862068966
# >> Type of Kernel  rbf <<
# 0.0 0.568965517241
# >> Type of Kernel  sigmoid <<
# 0.0 0.568965517241
# >> Penalty parameter C 0.644444444444 <<
# >> Type of Kernel  linear <<
# 0.5 0.879310344828
# >> Type of Kernel  rbf <<
# 0.5 0.603448275862
# >> Type of Kernel  sigmoid <<
# 0.0 0.568965517241
# >> Penalty parameter C 1.18888888889 <<
# >> Type of Kernel  linear <<
# 0.5 0.913793103448
# >> Type of Kernel  rbf <<
# 0.5 0.724137931034
# >> Type of Kernel  sigmoid <<
# 0.0 0.568965517241
# >> Penalty parameter C 1.73333333333 <<
# >> Type of Kernel  linear <<
# 0.5 0.948275862069
# >> Type of Kernel  rbf <<
# 0.5 0.758620689655
# >> Type of Kernel  sigmoid <<
# 0.0 0.568965517241
# >> Penalty parameter C 2.27777777778 <<
# >> Type of Kernel  linear <<
# 1.0 0.931034482759
# >> Type of Kernel  rbf <<
# 0.5 0.758620689655
# >> Type of Kernel  sigmoid <<
# 0.0 0.568965517241
# >> Penalty parameter C 2.82222222222 <<
# >> Type of Kernel  linear <<
# 1.0 0.948275862069
# >> Type of Kernel  rbf <<
# 0.5 0.810344827586
# >> Type of Kernel  sigmoid <<
# 0.0 0.586206896552
# >> Penalty parameter C 3.36666666667 <<
# >> Type of Kernel  linear <<
# 1.0 0.948275862069
# >> Type of Kernel  rbf <<
# 0.5 0.827586206897
# >> Type of Kernel  sigmoid <<
# 0.5 0.620689655172
# >> Penalty parameter C 3.91111111111 <<
# >> Type of Kernel  linear <<
# 1.0 0.965517241379
# >> Type of Kernel  rbf <<
# 0.5 0.827586206897
# >> Type of Kernel  sigmoid <<
# 0.5 0.655172413793
# >> Penalty parameter C 4.45555555556 <<
# >> Type of Kernel  linear <<
# 1.0 0.965517241379
# >> Type of Kernel  rbf <<
# 0.5 0.844827586207
# >> Type of Kernel  sigmoid <<
# 0.5 0.689655172414
# >> Penalty parameter C 5.0 <<
# >> Type of Kernel  linear <<
# 1.0 0.98275862069
# >> Type of Kernel  rbf <<
# 0.5 0.844827586207
# >> Type of Kernel  sigmoid <<
# 0.5 0.741379310345
# --- Fold 4 ---
# >> Penalty parameter C 0.1 <<
# >> Type of Kernel  linear <<
# 0.5 0.775862068966
# >> Type of Kernel  rbf <<
# 0.0 0.51724137931
# >> Type of Kernel  sigmoid <<
# 0.0 0.51724137931
# >> Penalty parameter C 0.644444444444 <<
# >> Type of Kernel  linear <<
# 0.5 0.913793103448
# >> Type of Kernel  rbf <<
# 0.5 0.706896551724
# >> Type of Kernel  sigmoid <<
# 0.0 0.51724137931
# >> Penalty parameter C 1.18888888889 <<
# >> Type of Kernel  linear <<
# 0.5 0.931034482759
# >> Type of Kernel  rbf <<
# 0.5 0.706896551724
# >> Type of Kernel  sigmoid <<
# 0.5 0.758620689655
# >> Penalty parameter C 1.73333333333 <<
# >> Type of Kernel  linear <<
# 0.5 0.948275862069
# >> Type of Kernel  rbf <<
# 0.5 0.741379310345
# >> Type of Kernel  sigmoid <<
# 0.5 0.724137931034
# >> Penalty parameter C 2.27777777778 <<
# >> Type of Kernel  linear <<
# 0.5 0.965517241379
# >> Type of Kernel  rbf <<
# 0.5 0.758620689655
# >> Type of Kernel  sigmoid <<
# 0.5 0.689655172414
# >> Penalty parameter C 2.82222222222 <<
# >> Type of Kernel  linear <<
# 0.5 0.965517241379
# >> Type of Kernel  rbf <<
# 0.5 0.775862068966
# >> Type of Kernel  sigmoid <<
# 0.5 0.672413793103
# >> Penalty parameter C 3.36666666667 <<
# >> Type of Kernel  linear <<
# 0.5 0.965517241379
# >> Type of Kernel  rbf <<
# 0.5 0.827586206897
# >> Type of Kernel  sigmoid <<
# 0.5 0.637931034483
# >> Penalty parameter C 3.91111111111 <<
# >> Type of Kernel  linear <<
# 0.5 0.965517241379
# >> Type of Kernel  rbf <<
# 0.5 0.827586206897
# >> Type of Kernel  sigmoid <<
# 0.5 0.706896551724
# >> Penalty parameter C 4.45555555556 <<
# >> Type of Kernel  linear <<
# 0.5 0.965517241379
# >> Type of Kernel  rbf <<
# 0.5 0.844827586207
# >> Type of Kernel  sigmoid <<
# 0.5 0.724137931034
# >> Penalty parameter C 5.0 <<
# >> Type of Kernel  linear <<
# 0.5 0.965517241379
# >> Type of Kernel  rbf <<
# 0.5 0.896551724138
# >> Type of Kernel  sigmoid <<
# 0.5 0.706896551724
# --- Fold 5 ---
# >> Penalty parameter C 0.1 <<
# >> Type of Kernel  linear <<
# 1.0 0.793103448276
# >> Type of Kernel  rbf <<
# 1.0 0.603448275862
# >> Type of Kernel  sigmoid <<
# 1.0 0.586206896552
# >> Penalty parameter C 0.644444444444 <<
# >> Type of Kernel  linear <<
# 1.0 0.896551724138
# >> Type of Kernel  rbf <<
# 1.0 0.689655172414
# >> Type of Kernel  sigmoid <<
# 1.0 0.586206896552
# >> Penalty parameter C 1.18888888889 <<
# >> Type of Kernel  linear <<
# 1.0 0.896551724138
# >> Type of Kernel  rbf <<
# 1.0 0.689655172414
# >> Type of Kernel  sigmoid <<
# 1.0 0.586206896552
# >> Penalty parameter C 1.73333333333 <<
# >> Type of Kernel  linear <<
# 1.0 0.948275862069
# >> Type of Kernel  rbf <<
# 1.0 0.741379310345
# >> Type of Kernel  sigmoid <<
# 1.0 0.603448275862
# >> Penalty parameter C 2.27777777778 <<
# >> Type of Kernel  linear <<
# 1.0 0.948275862069
# >> Type of Kernel  rbf <<
# 1.0 0.741379310345
# >> Type of Kernel  sigmoid <<
# 1.0 0.672413793103
# >> Penalty parameter C 2.82222222222 <<
# >> Type of Kernel  linear <<
# 1.0 0.948275862069
# >> Type of Kernel  rbf <<
# 1.0 0.741379310345
# >> Type of Kernel  sigmoid <<
# 1.0 0.672413793103
# >> Penalty parameter C 3.36666666667 <<
# >> Type of Kernel  linear <<
# 1.0 0.948275862069
# >> Type of Kernel  rbf <<
# 1.0 0.810344827586
# >> Type of Kernel  sigmoid <<
# 1.0 0.637931034483
# >> Penalty parameter C 3.91111111111 <<
# >> Type of Kernel  linear <<
# 1.0 0.965517241379
# >> Type of Kernel  rbf <<
# 1.0 0.810344827586
# >> Type of Kernel  sigmoid <<
# 1.0 0.655172413793
# >> Penalty parameter C 4.45555555556 <<
# >> Type of Kernel  linear <<
# 1.0 0.965517241379
# >> Type of Kernel  rbf <<
# 1.0 0.827586206897
# >> Type of Kernel  sigmoid <<
# 1.0 0.655172413793
# >> Penalty parameter C 5.0 <<
# >> Type of Kernel  linear <<
# 1.0 0.98275862069
# >> Type of Kernel  rbf <<
# 1.0 0.862068965517
# >> Type of Kernel  sigmoid <<
# 1.0 0.655172413793
# --- Fold 6 ---
# >> Penalty parameter C 0.1 <<
# >> Type of Kernel  linear <<
# 1.0 0.810344827586
# >> Type of Kernel  rbf <<
# 0.5 0.586206896552
# >> Type of Kernel  sigmoid <<
# 0.5 0.551724137931
# >> Penalty parameter C 0.644444444444 <<
# >> Type of Kernel  linear <<
# 1.0 0.862068965517
# >> Type of Kernel  rbf <<
# 0.5 0.603448275862
# >> Type of Kernel  sigmoid <<
# 0.5 0.551724137931
# >> Penalty parameter C 1.18888888889 <<
# >> Type of Kernel  linear <<
# 1.0 0.896551724138
# >> Type of Kernel  rbf <<
# 0.5 0.689655172414
# >> Type of Kernel  sigmoid <<
# 0.5 0.551724137931
# >> Penalty parameter C 1.73333333333 <<
# >> Type of Kernel  linear <<
# 0.5 0.931034482759
# >> Type of Kernel  rbf <<
# 1.0 0.724137931034
# >> Type of Kernel  sigmoid <<
# 0.5 0.551724137931
# >> Penalty parameter C 2.27777777778 <<
# >> Type of Kernel  linear <<
# 0.5 0.948275862069
# >> Type of Kernel  rbf <<
# 1.0 0.741379310345
# >> Type of Kernel  sigmoid <<
# 0.5 0.586206896552
# >> Penalty parameter C 2.82222222222 <<
# >> Type of Kernel  linear <<
# 0.5 0.965517241379
# >> Type of Kernel  rbf <<
# 1.0 0.758620689655
# >> Type of Kernel  sigmoid <<
# 0.5 0.655172413793
# >> Penalty parameter C 3.36666666667 <<
# >> Type of Kernel  linear <<
# 0.5 0.965517241379
# >> Type of Kernel  rbf <<
# 1.0 0.793103448276
# >> Type of Kernel  sigmoid <<
# 0.5 0.689655172414
# >> Penalty parameter C 3.91111111111 <<
# >> Type of Kernel  linear <<
# 0.5 0.98275862069
# >> Type of Kernel  rbf <<
# 1.0 0.810344827586
# >> Type of Kernel  sigmoid <<
# 0.5 0.672413793103
# >> Penalty parameter C 4.45555555556 <<
# >> Type of Kernel  linear <<
# 0.5 0.98275862069
# >> Type of Kernel  rbf <<
# 1.0 0.827586206897
# >> Type of Kernel  sigmoid <<
# 1.0 0.655172413793
# >> Penalty parameter C 5.0 <<
# >> Type of Kernel  linear <<
# 0.5 0.98275862069
# >> Type of Kernel  rbf <<
# 1.0 0.862068965517
# >> Type of Kernel  sigmoid <<
# 1.0 0.672413793103
# --- Fold 7 ---
# >> Penalty parameter C 0.1 <<
# >> Type of Kernel  linear <<
# 0.5 0.827586206897
# >> Type of Kernel  rbf <<
# 0.0 0.51724137931
# >> Type of Kernel  sigmoid <<
# 0.0 0.51724137931
# >> Penalty parameter C 0.644444444444 <<
# >> Type of Kernel  linear <<
# 0.0 0.896551724138
# >> Type of Kernel  rbf <<
# 0.0 0.586206896552
# >> Type of Kernel  sigmoid <<
# 0.0 0.51724137931
# >> Penalty parameter C 1.18888888889 <<
# >> Type of Kernel  linear <<
# 0.0 0.913793103448
# >> Type of Kernel  rbf <<
# 0.5 0.706896551724
# >> Type of Kernel  sigmoid <<
# 0.0 0.568965517241
# >> Penalty parameter C 1.73333333333 <<
# >> Type of Kernel  linear <<
# 0.0 0.931034482759
# >> Type of Kernel  rbf <<
# 0.5 0.741379310345
# >> Type of Kernel  sigmoid <<
# 0.0 0.568965517241
# >> Penalty parameter C 2.27777777778 <<
# >> Type of Kernel  linear <<
# 0.0 0.931034482759
# >> Type of Kernel  rbf <<
# 0.5 0.758620689655
# >> Type of Kernel  sigmoid <<
# 0.0 0.568965517241
# >> Penalty parameter C 2.82222222222 <<
# >> Type of Kernel  linear <<
# 0.0 0.931034482759
# >> Type of Kernel  rbf <<
# 0.5 0.810344827586
# >> Type of Kernel  sigmoid <<
# 0.0 0.586206896552
# >> Penalty parameter C 3.36666666667 <<
# >> Type of Kernel  linear <<
# 0.0 0.948275862069
# >> Type of Kernel  rbf <<
# 0.5 0.827586206897
# >> Type of Kernel  sigmoid <<
# 0.0 0.655172413793
# >> Penalty parameter C 3.91111111111 <<
# >> Type of Kernel  linear <<
# 0.0 0.948275862069
# >> Type of Kernel  rbf <<
# 0.5 0.844827586207
# >> Type of Kernel  sigmoid <<
# 0.0 0.672413793103
# >> Penalty parameter C 4.45555555556 <<
# >> Type of Kernel  linear <<
# 0.0 0.948275862069
# >> Type of Kernel  rbf <<
# 0.5 0.879310344828
# >> Type of Kernel  sigmoid <<
# 0.5 0.689655172414
# >> Penalty parameter C 5.0 <<
# >> Type of Kernel  linear <<
# 0.0 0.98275862069
# >> Type of Kernel  rbf <<
# 0.0 0.879310344828
# >> Type of Kernel  sigmoid <<
# 0.5 0.724137931034
# --- Fold 8 ---
# >> Penalty parameter C 0.1 <<
# >> Type of Kernel  linear <<
# 0.5 0.827586206897
# >> Type of Kernel  rbf <<
# 0.5 0.586206896552
# >> Type of Kernel  sigmoid <<
# 0.5 0.551724137931
# >> Penalty parameter C 0.644444444444 <<
# >> Type of Kernel  linear <<
# 0.5 0.931034482759
# >> Type of Kernel  rbf <<
# 0.5 0.603448275862
# >> Type of Kernel  sigmoid <<
# 0.5 0.551724137931
# >> Penalty parameter C 1.18888888889 <<
# >> Type of Kernel  linear <<
# 0.5 0.965517241379
# >> Type of Kernel  rbf <<
# 0.5 0.724137931034
# >> Type of Kernel  sigmoid <<
# 0.5 0.551724137931
# >> Penalty parameter C 1.73333333333 <<
# >> Type of Kernel  linear <<
# 0.5 0.965517241379
# >> Type of Kernel  rbf <<
# 0.5 0.741379310345
# >> Type of Kernel  sigmoid <<
# 0.5 0.551724137931
# >> Penalty parameter C 2.27777777778 <<
# >> Type of Kernel  linear <<
# 0.5 0.98275862069
# >> Type of Kernel  rbf <<
# 0.5 0.775862068966
# >> Type of Kernel  sigmoid <<
# 0.5 0.568965517241
# >> Penalty parameter C 2.82222222222 <<
# >> Type of Kernel  linear <<
# 0.5 0.98275862069
# >> Type of Kernel  rbf <<
# 0.5 0.810344827586
# >> Type of Kernel  sigmoid <<
# 0.5 0.655172413793
# >> Penalty parameter C 3.36666666667 <<
# >> Type of Kernel  linear <<
# 0.5 0.98275862069
# >> Type of Kernel  rbf <<
# 0.5 0.827586206897
# >> Type of Kernel  sigmoid <<
# 0.5 0.672413793103
# >> Penalty parameter C 3.91111111111 <<
# >> Type of Kernel  linear <<
# 0.5 0.98275862069
# >> Type of Kernel  rbf <<
# 0.5 0.844827586207
# >> Type of Kernel  sigmoid <<
# 0.5 0.689655172414
# >> Penalty parameter C 4.45555555556 <<
# >> Type of Kernel  linear <<
# 0.5 0.98275862069
# >> Type of Kernel  rbf <<
# 0.5 0.844827586207
# >> Type of Kernel  sigmoid <<
# 0.5 0.706896551724
# >> Penalty parameter C 5.0 <<
# >> Type of Kernel  linear <<
# 0.5 0.98275862069
# >> Type of Kernel  rbf <<
# 0.5 0.879310344828
# >> Type of Kernel  sigmoid <<
# 0.5 0.689655172414
# --- Fold 9 ---
# >> Penalty parameter C 0.1 <<
# >> Type of Kernel  linear <<
# 0.5 0.844827586207
# >> Type of Kernel  rbf <<
# 0.5 0.603448275862
# >> Type of Kernel  sigmoid <<
# 0.5 0.603448275862
# >> Penalty parameter C 0.644444444444 <<
# >> Type of Kernel  linear <<
# 0.5 0.862068965517
# >> Type of Kernel  rbf <<
# 0.5 0.620689655172
# >> Type of Kernel  sigmoid <<
# 0.5 0.603448275862
# >> Penalty parameter C 1.18888888889 <<
# >> Type of Kernel  linear <<
# 0.5 0.913793103448
# >> Type of Kernel  rbf <<
# 0.5 0.706896551724
# >> Type of Kernel  sigmoid <<
# 0.5 0.603448275862
# >> Penalty parameter C 1.73333333333 <<
# >> Type of Kernel  linear <<
# 1.0 0.931034482759
# >> Type of Kernel  rbf <<
# 0.5 0.741379310345
# >> Type of Kernel  sigmoid <<
# 0.5 0.672413793103
# >> Penalty parameter C 2.27777777778 <<
# >> Type of Kernel  linear <<
# 1.0 0.931034482759
# >> Type of Kernel  rbf <<
# 0.5 0.758620689655
# >> Type of Kernel  sigmoid <<
# 0.5 0.655172413793
# >> Penalty parameter C 2.82222222222 <<
# >> Type of Kernel  linear <<
# 1.0 0.948275862069
# >> Type of Kernel  rbf <<
# 0.5 0.793103448276
# >> Type of Kernel  sigmoid <<
# 0.5 0.689655172414
# >> Penalty parameter C 3.36666666667 <<
# >> Type of Kernel  linear <<
# 1.0 0.948275862069
# >> Type of Kernel  rbf <<
# 0.5 0.844827586207
# >> Type of Kernel  sigmoid <<
# 0.5 0.706896551724
# >> Penalty parameter C 3.91111111111 <<
# >> Type of Kernel  linear <<
# 1.0 0.965517241379
# >> Type of Kernel  rbf <<
# 0.5 0.862068965517
# >> Type of Kernel  sigmoid <<
# 0.5 0.672413793103
# >> Penalty parameter C 4.45555555556 <<
# >> Type of Kernel  linear <<
# 1.0 0.965517241379
# >> Type of Kernel  rbf <<
# 0.5 0.862068965517
# >> Type of Kernel  sigmoid <<
# 0.5 0.689655172414
# >> Penalty parameter C 5.0 <<
# >> Type of Kernel  linear <<
# 1.0 0.965517241379
# >> Type of Kernel  rbf <<
# 0.5 0.862068965517
# >> Type of Kernel  sigmoid <<
# 0.5 0.689655172414
# --- Fold 10 ---
# >> Penalty parameter C 0.1 <<
# >> Type of Kernel  linear <<
# 0.0 0.741379310345
# >> Type of Kernel  rbf <<
# 0.5 0.603448275862
# >> Type of Kernel  sigmoid <<
# 0.5 0.637931034483
# >> Penalty parameter C 0.644444444444 <<
# >> Type of Kernel  linear <<
# 0.5 0.896551724138
# >> Type of Kernel  rbf <<
# 0.0 0.689655172414
# >> Type of Kernel  sigmoid <<
# 0.5 0.637931034483
# >> Penalty parameter C 1.18888888889 <<
# >> Type of Kernel  linear <<
# 0.5 0.948275862069
# >> Type of Kernel  rbf <<
# 0.0 0.724137931034
# >> Type of Kernel  sigmoid <<
# 0.5 0.637931034483
# >> Penalty parameter C 1.73333333333 <<
# >> Type of Kernel  linear <<
# 0.5 0.948275862069
# >> Type of Kernel  rbf <<
# 0.0 0.724137931034
# >> Type of Kernel  sigmoid <<
# 0.0 0.655172413793
# >> Penalty parameter C 2.27777777778 <<
# >> Type of Kernel  linear <<
# 0.5 0.98275862069
# >> Type of Kernel  rbf <<
# 0.0 0.724137931034
# >> Type of Kernel  sigmoid <<
# 0.0 0.655172413793
# >> Penalty parameter C 2.82222222222 <<
# >> Type of Kernel  linear <<
# 0.5 1.0
# >> Type of Kernel  rbf <<
# 0.0 0.793103448276
# >> Type of Kernel  sigmoid <<
# 0.0 0.672413793103
# >> Penalty parameter C 3.36666666667 <<
# >> Type of Kernel  linear <<
# 0.5 1.0
# >> Type of Kernel  rbf <<
# 0.0 0.810344827586
# >> Type of Kernel  sigmoid <<
# 0.0 0.724137931034
# >> Penalty parameter C 3.91111111111 <<
# >> Type of Kernel  linear <<
# 0.5 1.0
# >> Type of Kernel  rbf <<
# 0.0 0.844827586207
# >> Type of Kernel  sigmoid <<
# 0.0 0.706896551724
# >> Penalty parameter C 4.45555555556 <<
# >> Type of Kernel  linear <<
# 0.5 1.0
# >> Type of Kernel  rbf <<
# 0.0 0.827586206897
# >> Type of Kernel  sigmoid <<
# 0.0 0.706896551724
# >> Penalty parameter C 5.0 <<
# >> Type of Kernel  linear <<
# 0.5 1.0
# >> Type of Kernel  rbf <<
# 0.0 0.844827586207
# >> Type of Kernel  sigmoid <<
# 0.0 0.706896551724
# --- Fold 11 ---
# >> Penalty parameter C 0.1 <<
# >> Type of Kernel  linear <<
# 0.5 0.827586206897
# >> Type of Kernel  rbf <<
# 0.0 0.51724137931
# >> Type of Kernel  sigmoid <<
# 0.0 0.51724137931
# >> Penalty parameter C 0.644444444444 <<
# >> Type of Kernel  linear <<
# 0.0 0.896551724138
# >> Type of Kernel  rbf <<
# 1.0 0.655172413793
# >> Type of Kernel  sigmoid <<
# 0.0 0.51724137931
# >> Penalty parameter C 1.18888888889 <<
# >> Type of Kernel  linear <<
# 0.0 0.931034482759
# >> Type of Kernel  rbf <<
# 1.0 0.706896551724
# >> Type of Kernel  sigmoid <<
# 0.0 0.534482758621
# >> Penalty parameter C 1.73333333333 <<
# >> Type of Kernel  linear <<
# 0.0 0.931034482759
# >> Type of Kernel  rbf <<
# 1.0 0.741379310345
# >> Type of Kernel  sigmoid <<
# 0.5 0.724137931034
# >> Penalty parameter C 2.27777777778 <<
# >> Type of Kernel  linear <<
# 0.0 0.948275862069
# >> Type of Kernel  rbf <<
# 1.0 0.775862068966
# >> Type of Kernel  sigmoid <<
# 0.5 0.724137931034
# >> Penalty parameter C 2.82222222222 <<
# >> Type of Kernel  linear <<
# 0.0 0.965517241379
# >> Type of Kernel  rbf <<
# 1.0 0.775862068966
# >> Type of Kernel  sigmoid <<
# 0.5 0.706896551724
# >> Penalty parameter C 3.36666666667 <<
# >> Type of Kernel  linear <<
# 0.5 0.98275862069
# >> Type of Kernel  rbf <<
# 0.5 0.775862068966
# >> Type of Kernel  sigmoid <<
# 0.5 0.689655172414
# >> Penalty parameter C 3.91111111111 <<
# >> Type of Kernel  linear <<
# 0.5 0.98275862069
# >> Type of Kernel  rbf <<
# 0.5 0.793103448276
# >> Type of Kernel  sigmoid <<
# 0.5 0.706896551724
# >> Penalty parameter C 4.45555555556 <<
# >> Type of Kernel  linear <<
# 0.5 0.98275862069
# >> Type of Kernel  rbf <<
# 0.5 0.810344827586
# >> Type of Kernel  sigmoid <<
# 0.5 0.724137931034
# >> Penalty parameter C 5.0 <<
# >> Type of Kernel  linear <<
# 0.5 0.98275862069
# >> Type of Kernel  rbf <<
# 0.5 0.827586206897
# >> Type of Kernel  sigmoid <<
# 0.5 0.706896551724
# --- Fold 12 ---
# >> Penalty parameter C 0.1 <<
# >> Type of Kernel  linear <<
# 0.0 0.862068965517
# >> Type of Kernel  rbf <<
# 0.0 0.51724137931
# >> Type of Kernel  sigmoid <<
# 0.0 0.51724137931
# >> Penalty parameter C 0.644444444444 <<
# >> Type of Kernel  linear <<
# 0.0 0.896551724138
# >> Type of Kernel  rbf <<
# 0.0 0.620689655172
# >> Type of Kernel  sigmoid <<
# 0.0 0.51724137931
# >> Penalty parameter C 1.18888888889 <<
# >> Type of Kernel  linear <<
# 0.0 0.931034482759
# >> Type of Kernel  rbf <<
# 0.0 0.706896551724
# >> Type of Kernel  sigmoid <<
# 0.0 0.568965517241
# >> Penalty parameter C 1.73333333333 <<
# >> Type of Kernel  linear <<
# 0.0 0.931034482759
# >> Type of Kernel  rbf <<
# 0.0 0.775862068966
# >> Type of Kernel  sigmoid <<
# 0.0 0.568965517241
# >> Penalty parameter C 2.27777777778 <<
# >> Type of Kernel  linear <<
# 0.0 0.965517241379
# >> Type of Kernel  rbf <<
# 0.0 0.775862068966
# >> Type of Kernel  sigmoid <<
# 0.0 0.620689655172
# >> Penalty parameter C 2.82222222222 <<
# >> Type of Kernel  linear <<
# 0.0 0.965517241379
# >> Type of Kernel  rbf <<
# 0.0 0.775862068966
# >> Type of Kernel  sigmoid <<
# 0.0 0.637931034483
# >> Penalty parameter C 3.36666666667 <<
# >> Type of Kernel  linear <<
# 0.5 0.965517241379
# >> Type of Kernel  rbf <<
# 0.0 0.827586206897
# >> Type of Kernel  sigmoid <<
# 0.0 0.706896551724
# >> Penalty parameter C 3.91111111111 <<
# >> Type of Kernel  linear <<
# 0.5 0.965517241379
# >> Type of Kernel  rbf <<
# 0.0 0.827586206897
# >> Type of Kernel  sigmoid <<
# 0.0 0.706896551724
# >> Penalty parameter C 4.45555555556 <<
# >> Type of Kernel  linear <<
# 0.5 0.965517241379
# >> Type of Kernel  rbf <<
# 0.0 0.844827586207
# >> Type of Kernel  sigmoid <<
# 0.0 0.706896551724
# >> Penalty parameter C 5.0 <<
# >> Type of Kernel  linear <<
# 0.5 0.98275862069
# >> Type of Kernel  rbf <<
# 0.0 0.879310344828
# >> Type of Kernel  sigmoid <<
# 0.0 0.637931034483
# --- Fold 13 ---
# >> Penalty parameter C 0.1 <<
# >> Type of Kernel  linear <<
# 1.0 0.810344827586
# >> Type of Kernel  rbf <<
# 0.5 0.586206896552
# >> Type of Kernel  sigmoid <<
# 0.5 0.551724137931
# >> Penalty parameter C 0.644444444444 <<
# >> Type of Kernel  linear <<
# 0.5 0.844827586207
# >> Type of Kernel  rbf <<
# 0.5 0.603448275862
# >> Type of Kernel  sigmoid <<
# 0.5 0.551724137931
# >> Penalty parameter C 1.18888888889 <<
# >> Type of Kernel  linear <<
# 0.5 0.896551724138
# >> Type of Kernel  rbf <<
# 1.0 0.689655172414
# >> Type of Kernel  sigmoid <<
# 0.5 0.551724137931
# >> Penalty parameter C 1.73333333333 <<
# >> Type of Kernel  linear <<
# 0.5 0.948275862069
# >> Type of Kernel  rbf <<
# 1.0 0.724137931034
# >> Type of Kernel  sigmoid <<
# 0.5 0.586206896552
# >> Penalty parameter C 2.27777777778 <<
# >> Type of Kernel  linear <<
# 0.5 0.948275862069
# >> Type of Kernel  rbf <<
# 1.0 0.741379310345
# >> Type of Kernel  sigmoid <<
# 0.5 0.603448275862
# >> Penalty parameter C 2.82222222222 <<
# >> Type of Kernel  linear <<
# 0.5 0.948275862069
# >> Type of Kernel  rbf <<
# 1.0 0.793103448276
# >> Type of Kernel  sigmoid <<
# 1.0 0.637931034483
# >> Penalty parameter C 3.36666666667 <<
# >> Type of Kernel  linear <<
# 0.5 0.965517241379
# >> Type of Kernel  rbf <<
# 1.0 0.793103448276
# >> Type of Kernel  sigmoid <<
# 1.0 0.689655172414
# >> Penalty parameter C 3.91111111111 <<
# >> Type of Kernel  linear <<
# 0.5 0.965517241379
# >> Type of Kernel  rbf <<
# 1.0 0.810344827586
# >> Type of Kernel  sigmoid <<
# 1.0 0.672413793103
# >> Penalty parameter C 4.45555555556 <<
# >> Type of Kernel  linear <<
# 0.5 0.965517241379
# >> Type of Kernel  rbf <<
# 1.0 0.827586206897
# >> Type of Kernel  sigmoid <<
# 1.0 0.672413793103
# >> Penalty parameter C 5.0 <<
# >> Type of Kernel  linear <<
# 0.5 0.98275862069
# >> Type of Kernel  rbf <<
# 1.0 0.862068965517
# >> Type of Kernel  sigmoid <<
# 1.0 0.672413793103
# --- Fold 14 ---
# >> Penalty parameter C 0.1 <<
# >> Type of Kernel  linear <<
# 1.0 0.793103448276
# >> Type of Kernel  rbf <<
# 0.0 0.51724137931
# >> Type of Kernel  sigmoid <<
# 0.0 0.51724137931
# >> Penalty parameter C 0.644444444444 <<
# >> Type of Kernel  linear <<
# 1.0 0.844827586207
# >> Type of Kernel  rbf <<
# 0.5 0.603448275862
# >> Type of Kernel  sigmoid <<
# 0.0 0.51724137931
# >> Penalty parameter C 1.18888888889 <<
# >> Type of Kernel  linear <<
# 1.0 0.879310344828
# >> Type of Kernel  rbf <<
# 1.0 0.724137931034
# >> Type of Kernel  sigmoid <<
# 0.5 0.568965517241
# >> Penalty parameter C 1.73333333333 <<
# >> Type of Kernel  linear <<
# 1.0 0.948275862069
# >> Type of Kernel  rbf <<
# 1.0 0.724137931034
# >> Type of Kernel  sigmoid <<
# 0.5 0.551724137931
# >> Penalty parameter C 2.27777777778 <<
# >> Type of Kernel  linear <<
# 1.0 0.948275862069
# >> Type of Kernel  rbf <<
# 1.0 0.741379310345
# >> Type of Kernel  sigmoid <<
# 0.5 0.603448275862
# >> Penalty parameter C 2.82222222222 <<
# >> Type of Kernel  linear <<
# 1.0 0.948275862069
# >> Type of Kernel  rbf <<
# 1.0 0.793103448276
# >> Type of Kernel  sigmoid <<
# 0.5 0.655172413793
# >> Penalty parameter C 3.36666666667 <<
# >> Type of Kernel  linear <<
# 1.0 0.948275862069
# >> Type of Kernel  rbf <<
# 1.0 0.810344827586
# >> Type of Kernel  sigmoid <<
# 0.5 0.689655172414
# >> Penalty parameter C 3.91111111111 <<
# >> Type of Kernel  linear <<
# 1.0 0.965517241379
# >> Type of Kernel  rbf <<
# 1.0 0.810344827586
# >> Type of Kernel  sigmoid <<
# 0.5 0.706896551724
# >> Penalty parameter C 4.45555555556 <<
# >> Type of Kernel  linear <<
# 1.0 0.965517241379
# >> Type of Kernel  rbf <<
# 1.0 0.844827586207
# >> Type of Kernel  sigmoid <<
# 0.5 0.706896551724
# >> Penalty parameter C 5.0 <<
# >> Type of Kernel  linear <<
# 1.0 0.98275862069
# >> Type of Kernel  rbf <<
# 1.0 0.862068965517
# >> Type of Kernel  sigmoid <<
# 0.5 0.689655172414
# --- Fold 15 ---
# >> Penalty parameter C 0.1 <<
# >> Type of Kernel  linear <<
# 0.5 0.810344827586
# >> Type of Kernel  rbf <<
# 0.5 0.603448275862
# >> Type of Kernel  sigmoid <<
# 0.5 0.551724137931
# >> Penalty parameter C 0.644444444444 <<
# >> Type of Kernel  linear <<
# 0.5 0.862068965517
# >> Type of Kernel  rbf <<
# 0.5 0.620689655172
# >> Type of Kernel  sigmoid <<
# 0.5 0.551724137931
# >> Penalty parameter C 1.18888888889 <<
# >> Type of Kernel  linear <<
# 0.5 0.913793103448
# >> Type of Kernel  rbf <<
# 0.5 0.706896551724
# >> Type of Kernel  sigmoid <<
# 0.5 0.551724137931
# >> Penalty parameter C 1.73333333333 <<
# >> Type of Kernel  linear <<
# 0.5 0.948275862069
# >> Type of Kernel  rbf <<
# 0.5 0.741379310345
# >> Type of Kernel  sigmoid <<
# 0.5 0.603448275862
# >> Penalty parameter C 2.27777777778 <<
# >> Type of Kernel  linear <<
# 0.5 0.948275862069
# >> Type of Kernel  rbf <<
# 0.5 0.775862068966
# >> Type of Kernel  sigmoid <<
# 0.5 0.603448275862
# >> Penalty parameter C 2.82222222222 <<
# >> Type of Kernel  linear <<
# 0.5 0.948275862069
# >> Type of Kernel  rbf <<
# 0.5 0.793103448276
# >> Type of Kernel  sigmoid <<
# 0.5 0.672413793103
# >> Penalty parameter C 3.36666666667 <<
# >> Type of Kernel  linear <<
# 0.5 0.948275862069
# >> Type of Kernel  rbf <<
# 0.5 0.810344827586
# >> Type of Kernel  sigmoid <<
# 0.5 0.689655172414
# >> Penalty parameter C 3.91111111111 <<
# >> Type of Kernel  linear <<
# 0.5 0.948275862069
# >> Type of Kernel  rbf <<
# 0.5 0.810344827586
# >> Type of Kernel  sigmoid <<
# 0.5 0.655172413793
# >> Penalty parameter C 4.45555555556 <<
# >> Type of Kernel  linear <<
# 0.5 0.948275862069
# >> Type of Kernel  rbf <<
# 0.5 0.827586206897
# >> Type of Kernel  sigmoid <<
# 0.5 0.655172413793
# >> Penalty parameter C 5.0 <<
# >> Type of Kernel  linear <<
# 1.0 0.948275862069
# >> Type of Kernel  rbf <<
# 0.5 0.862068965517
# >> Type of Kernel  sigmoid <<
# 0.5 0.689655172414
# --- Fold 16 ---
# >> Penalty parameter C 0.1 <<
# >> Type of Kernel  linear <<
# 1.0 0.810344827586
# >> Type of Kernel  rbf <<
# 0.5 0.603448275862
# >> Type of Kernel  sigmoid <<
# 0.5 0.551724137931
# >> Penalty parameter C 0.644444444444 <<
# >> Type of Kernel  linear <<
# 1.0 0.862068965517
# >> Type of Kernel  rbf <<
# 0.5 0.620689655172
# >> Type of Kernel  sigmoid <<
# 0.5 0.551724137931
# >> Penalty parameter C 1.18888888889 <<
# >> Type of Kernel  linear <<
# 1.0 0.913793103448
# >> Type of Kernel  rbf <<
# 1.0 0.689655172414
# >> Type of Kernel  sigmoid <<
# 0.5 0.551724137931
# >> Penalty parameter C 1.73333333333 <<
# >> Type of Kernel  linear <<
# 1.0 0.931034482759
# >> Type of Kernel  rbf <<
# 1.0 0.724137931034
# >> Type of Kernel  sigmoid <<
# 0.5 0.620689655172
# >> Penalty parameter C 2.27777777778 <<
# >> Type of Kernel  linear <<
# 1.0 0.948275862069
# >> Type of Kernel  rbf <<
# 1.0 0.741379310345
# >> Type of Kernel  sigmoid <<
# 0.5 0.603448275862
# >> Penalty parameter C 2.82222222222 <<
# >> Type of Kernel  linear <<
# 1.0 0.948275862069
# >> Type of Kernel  rbf <<
# 1.0 0.793103448276
# >> Type of Kernel  sigmoid <<
# 0.5 0.655172413793
# >> Penalty parameter C 3.36666666667 <<
# >> Type of Kernel  linear <<
# 1.0 0.965517241379
# >> Type of Kernel  rbf <<
# 1.0 0.810344827586
# >> Type of Kernel  sigmoid <<
# 1.0 0.689655172414
# >> Penalty parameter C 3.91111111111 <<
# >> Type of Kernel  linear <<
# 1.0 0.965517241379
# >> Type of Kernel  rbf <<
# 1.0 0.827586206897
# >> Type of Kernel  sigmoid <<
# 1.0 0.672413793103
# >> Penalty parameter C 4.45555555556 <<
# >> Type of Kernel  linear <<
# 1.0 0.98275862069
# >> Type of Kernel  rbf <<
# 1.0 0.810344827586
# >> Type of Kernel  sigmoid <<
# 1.0 0.672413793103
# >> Penalty parameter C 5.0 <<
# >> Type of Kernel  linear <<
# 1.0 0.98275862069
# >> Type of Kernel  rbf <<
# 1.0 0.827586206897
# >> Type of Kernel  sigmoid <<
# 1.0 0.655172413793
# --- Fold 17 ---
# >> Penalty parameter C 0.1 <<
# >> Type of Kernel  linear <<
# 0.5 0.844827586207
# >> Type of Kernel  rbf <<
# 0.0 0.51724137931
# >> Type of Kernel  sigmoid <<
# 0.0 0.51724137931
# >> Penalty parameter C 0.644444444444 <<
# >> Type of Kernel  linear <<
# 0.5 0.896551724138
# >> Type of Kernel  rbf <<
# 0.5 0.603448275862
# >> Type of Kernel  sigmoid <<
# 0.0 0.51724137931
# >> Penalty parameter C 1.18888888889 <<
# >> Type of Kernel  linear <<
# 0.5 0.931034482759
# >> Type of Kernel  rbf <<
# 0.5 0.741379310345
# >> Type of Kernel  sigmoid <<
# 0.5 0.568965517241
# >> Penalty parameter C 1.73333333333 <<
# >> Type of Kernel  linear <<
# 0.5 0.948275862069
# >> Type of Kernel  rbf <<
# 0.5 0.775862068966
# >> Type of Kernel  sigmoid <<
# 0.5 0.551724137931
# >> Penalty parameter C 2.27777777778 <<
# >> Type of Kernel  linear <<
# 0.5 0.965517241379
# >> Type of Kernel  rbf <<
# 0.0 0.758620689655
# >> Type of Kernel  sigmoid <<
# 0.5 0.603448275862
# >> Penalty parameter C 2.82222222222 <<
# >> Type of Kernel  linear <<
# 0.5 0.948275862069
# >> Type of Kernel  rbf <<
# 0.0 0.844827586207
# >> Type of Kernel  sigmoid <<
# 0.5 0.637931034483
# >> Penalty parameter C 3.36666666667 <<
# >> Type of Kernel  linear <<
# 0.5 0.98275862069
# >> Type of Kernel  rbf <<
# 0.0 0.827586206897
# >> Type of Kernel  sigmoid <<
# 0.5 0.689655172414
# >> Penalty parameter C 3.91111111111 <<
# >> Type of Kernel  linear <<
# 0.5 0.98275862069
# >> Type of Kernel  rbf <<
# 0.0 0.862068965517
# >> Type of Kernel  sigmoid <<
# 0.5 0.689655172414
# >> Penalty parameter C 4.45555555556 <<
# >> Type of Kernel  linear <<
# 0.5 0.98275862069
# >> Type of Kernel  rbf <<
# 0.0 0.879310344828
# >> Type of Kernel  sigmoid <<
# 0.5 0.689655172414
# >> Penalty parameter C 5.0 <<
# >> Type of Kernel  linear <<
# 0.5 0.98275862069
# >> Type of Kernel  rbf <<
# 0.0 0.879310344828
# >> Type of Kernel  sigmoid <<
# 0.5 0.689655172414
# --- Fold 18 ---
# >> Penalty parameter C 0.1 <<
# >> Type of Kernel  linear <<
# 0.5 0.844827586207
# >> Type of Kernel  rbf <<
# 0.0 0.51724137931
# >> Type of Kernel  sigmoid <<
# 0.0 0.51724137931
# >> Penalty parameter C 0.644444444444 <<
# >> Type of Kernel  linear <<
# 0.5 0.879310344828
# >> Type of Kernel  rbf <<
# 0.5 0.655172413793
# >> Type of Kernel  sigmoid <<
# 0.0 0.51724137931
# >> Penalty parameter C 1.18888888889 <<
# >> Type of Kernel  linear <<
# 0.5 0.913793103448
# >> Type of Kernel  rbf <<
# 0.5 0.672413793103
# >> Type of Kernel  sigmoid <<
# 0.0 0.534482758621
# >> Penalty parameter C 1.73333333333 <<
# >> Type of Kernel  linear <<
# 0.5 0.948275862069
# >> Type of Kernel  rbf <<
# 0.5 0.741379310345
# >> Type of Kernel  sigmoid <<
# 0.5 0.758620689655
# >> Penalty parameter C 2.27777777778 <<
# >> Type of Kernel  linear <<
# 0.5 0.965517241379
# >> Type of Kernel  rbf <<
# 0.5 0.793103448276
# >> Type of Kernel  sigmoid <<
# 0.5 0.724137931034
# >> Penalty parameter C 2.82222222222 <<
# >> Type of Kernel  linear <<
# 0.5 0.965517241379
# >> Type of Kernel  rbf <<
# 0.5 0.827586206897
# >> Type of Kernel  sigmoid <<
# 0.5 0.724137931034
# >> Penalty parameter C 3.36666666667 <<
# >> Type of Kernel  linear <<
# 0.5 0.965517241379
# >> Type of Kernel  rbf <<
# 0.5 0.862068965517
# >> Type of Kernel  sigmoid <<
# 0.5 0.689655172414
# >> Penalty parameter C 3.91111111111 <<
# >> Type of Kernel  linear <<
# 0.5 0.965517241379
# >> Type of Kernel  rbf <<
# 0.5 0.844827586207
# >> Type of Kernel  sigmoid <<
# 0.5 0.724137931034
# >> Penalty parameter C 4.45555555556 <<
# >> Type of Kernel  linear <<
# 0.5 0.98275862069
# >> Type of Kernel  rbf <<
# 0.5 0.862068965517
# >> Type of Kernel  sigmoid <<
# 0.5 0.724137931034
# >> Penalty parameter C 5.0 <<
# >> Type of Kernel  linear <<
# 0.5 0.98275862069
# >> Type of Kernel  rbf <<
# 0.5 0.862068965517
# >> Type of Kernel  sigmoid <<
# 0.5 0.706896551724
# --- Fold 19 ---
# >> Penalty parameter C 0.1 <<
# >> Type of Kernel  linear <<
# 1.0 0.793103448276
# >> Type of Kernel  rbf <<
# 0.5 0.568965517241
# >> Type of Kernel  sigmoid <<
# 0.5 0.551724137931
# >> Penalty parameter C 0.644444444444 <<
# >> Type of Kernel  linear <<
# 1.0 0.896551724138
# >> Type of Kernel  rbf <<
# 1.0 0.586206896552
# >> Type of Kernel  sigmoid <<
# 0.5 0.551724137931
# >> Penalty parameter C 1.18888888889 <<
# >> Type of Kernel  linear <<
# 1.0 0.879310344828
# >> Type of Kernel  rbf <<
# 1.0 0.724137931034
# >> Type of Kernel  sigmoid <<
# 0.5 0.551724137931
# >> Penalty parameter C 1.73333333333 <<
# >> Type of Kernel  linear <<
# 1.0 0.948275862069
# >> Type of Kernel  rbf <<
# 1.0 0.724137931034
# >> Type of Kernel  sigmoid <<
# 0.5 0.551724137931
# >> Penalty parameter C 2.27777777778 <<
# >> Type of Kernel  linear <<
# 1.0 0.948275862069
# >> Type of Kernel  rbf <<
# 1.0 0.758620689655
# >> Type of Kernel  sigmoid <<
# 0.5 0.551724137931
# >> Penalty parameter C 2.82222222222 <<
# >> Type of Kernel  linear <<
# 1.0 0.948275862069
# >> Type of Kernel  rbf <<
# 1.0 0.775862068966
# >> Type of Kernel  sigmoid <<
# 1.0 0.603448275862
# >> Penalty parameter C 3.36666666667 <<
# >> Type of Kernel  linear <<
# 1.0 0.948275862069
# >> Type of Kernel  rbf <<
# 1.0 0.793103448276
# >> Type of Kernel  sigmoid <<
# 1.0 0.655172413793
# >> Penalty parameter C 3.91111111111 <<
# >> Type of Kernel  linear <<
# 1.0 0.965517241379
# >> Type of Kernel  rbf <<
# 1.0 0.810344827586
# >> Type of Kernel  sigmoid <<
# 1.0 0.672413793103
# >> Penalty parameter C 4.45555555556 <<
# >> Type of Kernel  linear <<
# 1.0 0.965517241379
# >> Type of Kernel  rbf <<
# 1.0 0.827586206897
# >> Type of Kernel  sigmoid <<
# 1.0 0.689655172414
# >> Penalty parameter C 5.0 <<
# >> Type of Kernel  linear <<
# 1.0 0.98275862069
# >> Type of Kernel  rbf <<
# 1.0 0.827586206897
# >> Type of Kernel  sigmoid <<
# 1.0 0.655172413793
# --- Fold 20 ---
# >> Penalty parameter C 0.1 <<
# >> Type of Kernel  linear <<
# 1.0 0.810344827586
# >> Type of Kernel  rbf <<
# 1.0 0.586206896552
# >> Type of Kernel  sigmoid <<
# 1.0 0.620689655172
# >> Penalty parameter C 0.644444444444 <<
# >> Type of Kernel  linear <<
# 0.5 0.913793103448
# >> Type of Kernel  rbf <<
# 1.0 0.620689655172
# >> Type of Kernel  sigmoid <<
# 1.0 0.620689655172
# >> Penalty parameter C 1.18888888889 <<
# >> Type of Kernel  linear <<
# 0.5 0.913793103448
# >> Type of Kernel  rbf <<
# 1.0 0.724137931034
# >> Type of Kernel  sigmoid <<
# 1.0 0.620689655172
# >> Penalty parameter C 1.73333333333 <<
# >> Type of Kernel  linear <<
# 0.5 0.913793103448
# >> Type of Kernel  rbf <<
# 1.0 0.741379310345
# >> Type of Kernel  sigmoid <<
# 1.0 0.655172413793
# >> Penalty parameter C 2.27777777778 <<
# >> Type of Kernel  linear <<
# 0.5 0.931034482759
# >> Type of Kernel  rbf <<
# 1.0 0.758620689655
# >> Type of Kernel  sigmoid <<
# 1.0 0.603448275862
# >> Penalty parameter C 2.82222222222 <<
# >> Type of Kernel  linear <<
# 0.5 0.965517241379
# >> Type of Kernel  rbf <<
# 1.0 0.775862068966
# >> Type of Kernel  sigmoid <<
# 1.0 0.672413793103
# >> Penalty parameter C 3.36666666667 <<
# >> Type of Kernel  linear <<
# 0.5 0.98275862069
# >> Type of Kernel  rbf <<
# 1.0 0.793103448276
# >> Type of Kernel  sigmoid <<
# 1.0 0.655172413793
# >> Penalty parameter C 3.91111111111 <<
# >> Type of Kernel  linear <<
# 0.5 0.98275862069
# >> Type of Kernel  rbf <<
# 1.0 0.793103448276
# >> Type of Kernel  sigmoid <<
# 1.0 0.689655172414
# >> Penalty parameter C 4.45555555556 <<
# >> Type of Kernel  linear <<
# 0.5 0.98275862069
# >> Type of Kernel  rbf <<
# 0.5 0.810344827586
# >> Type of Kernel  sigmoid <<
# 1.0 0.672413793103
# >> Penalty parameter C 5.0 <<
# >> Type of Kernel  linear <<
# 0.5 0.98275862069
# >> Type of Kernel  rbf <<
# 0.5 0.827586206897
# >> Type of Kernel  sigmoid <<
# 1.0 0.672413793103
# --- Fold 21 ---
# >> Penalty parameter C 0.1 <<
# >> Type of Kernel  linear <<
# 1.0 0.810344827586
# >> Type of Kernel  rbf <<
# 0.5 0.603448275862
# >> Type of Kernel  sigmoid <<
# 0.5 0.551724137931
# >> Penalty parameter C 0.644444444444 <<
# >> Type of Kernel  linear <<
# 1.0 0.879310344828
# >> Type of Kernel  rbf <<
# 0.5 0.620689655172
# >> Type of Kernel  sigmoid <<
# 0.5 0.551724137931
# >> Penalty parameter C 1.18888888889 <<
# >> Type of Kernel  linear <<
# 1.0 0.896551724138
# >> Type of Kernel  rbf <<
# 0.5 0.724137931034
# >> Type of Kernel  sigmoid <<
# 0.5 0.551724137931
# >> Penalty parameter C 1.73333333333 <<
# >> Type of Kernel  linear <<
# 1.0 0.948275862069
# >> Type of Kernel  rbf <<
# 1.0 0.741379310345
# >> Type of Kernel  sigmoid <<
# 0.5 0.603448275862
# >> Penalty parameter C 2.27777777778 <<
# >> Type of Kernel  linear <<
# 1.0 0.948275862069
# >> Type of Kernel  rbf <<
# 1.0 0.775862068966
# >> Type of Kernel  sigmoid <<
# 0.5 0.603448275862
# >> Penalty parameter C 2.82222222222 <<
# >> Type of Kernel  linear <<
# 1.0 0.948275862069
# >> Type of Kernel  rbf <<
# 1.0 0.758620689655
# >> Type of Kernel  sigmoid <<
# 0.5 0.672413793103
# >> Penalty parameter C 3.36666666667 <<
# >> Type of Kernel  linear <<
# 1.0 0.948275862069
# >> Type of Kernel  rbf <<
# 1.0 0.775862068966
# >> Type of Kernel  sigmoid <<
# 0.5 0.672413793103
# >> Penalty parameter C 3.91111111111 <<
# >> Type of Kernel  linear <<
# 1.0 0.965517241379
# >> Type of Kernel  rbf <<
# 1.0 0.810344827586
# >> Type of Kernel  sigmoid <<
# 0.5 0.637931034483
# >> Penalty parameter C 4.45555555556 <<
# >> Type of Kernel  linear <<
# 1.0 0.965517241379
# >> Type of Kernel  rbf <<
# 1.0 0.810344827586
# >> Type of Kernel  sigmoid <<
# 0.5 0.655172413793
# >> Penalty parameter C 5.0 <<
# >> Type of Kernel  linear <<
# 1.0 0.98275862069
# >> Type of Kernel  rbf <<
# 1.0 0.844827586207
# >> Type of Kernel  sigmoid <<
# 1.0 0.655172413793
# --- Fold 22 ---
# >> Penalty parameter C 0.1 <<
# >> Type of Kernel  linear <<
# 1.0 0.793103448276
# >> Type of Kernel  rbf <<
# 0.5 0.603448275862
# >> Type of Kernel  sigmoid <<
# 0.5 0.586206896552
# >> Penalty parameter C 0.644444444444 <<
# >> Type of Kernel  linear <<
# 1.0 0.896551724138
# >> Type of Kernel  rbf <<
# 0.5 0.620689655172
# >> Type of Kernel  sigmoid <<
# 0.5 0.586206896552
# >> Penalty parameter C 1.18888888889 <<
# >> Type of Kernel  linear <<
# 1.0 0.896551724138
# >> Type of Kernel  rbf <<
# 1.0 0.655172413793
# >> Type of Kernel  sigmoid <<
# 0.5 0.586206896552
# >> Penalty parameter C 1.73333333333 <<
# >> Type of Kernel  linear <<
# 1.0 0.948275862069
# >> Type of Kernel  rbf <<
# 1.0 0.741379310345
# >> Type of Kernel  sigmoid <<
# 0.5 0.637931034483
# >> Penalty parameter C 2.27777777778 <<
# >> Type of Kernel  linear <<
# 1.0 0.948275862069
# >> Type of Kernel  rbf <<
# 1.0 0.758620689655
# >> Type of Kernel  sigmoid <<
# 0.5 0.620689655172
# >> Penalty parameter C 2.82222222222 <<
# >> Type of Kernel  linear <<
# 1.0 0.948275862069
# >> Type of Kernel  rbf <<
# 1.0 0.758620689655
# >> Type of Kernel  sigmoid <<
# 0.5 0.672413793103
# >> Penalty parameter C 3.36666666667 <<
# >> Type of Kernel  linear <<
# 1.0 0.948275862069
# >> Type of Kernel  rbf <<
# 1.0 0.810344827586
# >> Type of Kernel  sigmoid <<
# 1.0 0.655172413793
# >> Penalty parameter C 3.91111111111 <<
# >> Type of Kernel  linear <<
# 1.0 0.965517241379
# >> Type of Kernel  rbf <<
# 1.0 0.810344827586
# >> Type of Kernel  sigmoid <<
# 1.0 0.620689655172
# >> Penalty parameter C 4.45555555556 <<
# >> Type of Kernel  linear <<
# 1.0 0.965517241379
# >> Type of Kernel  rbf <<
# 1.0 0.827586206897
# >> Type of Kernel  sigmoid <<
# 1.0 0.672413793103
# >> Penalty parameter C 5.0 <<
# >> Type of Kernel  linear <<
# 1.0 0.98275862069
# >> Type of Kernel  rbf <<
# 1.0 0.862068965517
# >> Type of Kernel  sigmoid <<
# 1.0 0.672413793103
# --- Fold 23 ---
# >> Penalty parameter C 0.1 <<
# >> Type of Kernel  linear <<
# 0.0 0.775862068966
# >> Type of Kernel  rbf <<
# 0.5 0.603448275862
# >> Type of Kernel  sigmoid <<
# 0.5 0.603448275862
# >> Penalty parameter C 0.644444444444 <<
# >> Type of Kernel  linear <<
# 0.5 0.879310344828
# >> Type of Kernel  rbf <<
# 0.5 0.637931034483
# >> Type of Kernel  sigmoid <<
# 0.5 0.603448275862
# >> Penalty parameter C 1.18888888889 <<
# >> Type of Kernel  linear <<
# 0.0 0.948275862069
# >> Type of Kernel  rbf <<
# 0.5 0.689655172414
# >> Type of Kernel  sigmoid <<
# 0.5 0.603448275862
# >> Penalty parameter C 1.73333333333 <<
# >> Type of Kernel  linear <<
# 0.5 0.965517241379
# >> Type of Kernel  rbf <<
# 0.5 0.706896551724
# >> Type of Kernel  sigmoid <<
# 0.5 0.620689655172
# >> Penalty parameter C 2.27777777778 <<
# >> Type of Kernel  linear <<
# 0.5 0.948275862069
# >> Type of Kernel  rbf <<
# 0.0 0.724137931034
# >> Type of Kernel  sigmoid <<
# 0.5 0.689655172414
# >> Penalty parameter C 2.82222222222 <<
# >> Type of Kernel  linear <<
# 0.5 0.98275862069
# >> Type of Kernel  rbf <<
# 0.0 0.775862068966
# >> Type of Kernel  sigmoid <<
# 0.5 0.672413793103
# >> Penalty parameter C 3.36666666667 <<
# >> Type of Kernel  linear <<
# 0.5 0.98275862069
# >> Type of Kernel  rbf <<
# 0.0 0.793103448276
# >> Type of Kernel  sigmoid <<
# 0.0 0.672413793103
# >> Penalty parameter C 3.91111111111 <<
# >> Type of Kernel  linear <<
# 0.5 0.98275862069
# >> Type of Kernel  rbf <<
# 0.0 0.793103448276
# >> Type of Kernel  sigmoid <<
# 0.0 0.724137931034
# >> Penalty parameter C 4.45555555556 <<
# >> Type of Kernel  linear <<
# 0.5 0.98275862069
# >> Type of Kernel  rbf <<
# 0.5 0.793103448276
# >> Type of Kernel  sigmoid <<
# 0.0 0.706896551724
# >> Penalty parameter C 5.0 <<
# >> Type of Kernel  linear <<
# 0.5 0.98275862069
# >> Type of Kernel  rbf <<
# 0.5 0.827586206897
# >> Type of Kernel  sigmoid <<
# 0.0 0.706896551724
# --- Fold 24 ---
# >> Penalty parameter C 0.1 <<
# >> Type of Kernel  linear <<
# 0.5 0.775862068966
# >> Type of Kernel  rbf <<
# 0.0 0.51724137931
# >> Type of Kernel  sigmoid <<
# 0.0 0.51724137931
# >> Penalty parameter C 0.644444444444 <<
# >> Type of Kernel  linear <<
# 0.5 0.913793103448
# >> Type of Kernel  rbf <<
# 0.5 0.689655172414
# >> Type of Kernel  sigmoid <<
# 0.0 0.51724137931
# >> Penalty parameter C 1.18888888889 <<
# >> Type of Kernel  linear <<
# 0.5 0.931034482759
# >> Type of Kernel  rbf <<
# 0.5 0.689655172414
# >> Type of Kernel  sigmoid <<
# 0.5 0.51724137931
# >> Penalty parameter C 1.73333333333 <<
# >> Type of Kernel  linear <<
# 0.5 0.965517241379
# >> Type of Kernel  rbf <<
# 0.5 0.706896551724
# >> Type of Kernel  sigmoid <<
# 0.5 0.775862068966
# >> Penalty parameter C 2.27777777778 <<
# >> Type of Kernel  linear <<
# 0.5 0.965517241379
# >> Type of Kernel  rbf <<
# 0.5 0.724137931034
# >> Type of Kernel  sigmoid <<
# 0.5 0.672413793103
# >> Penalty parameter C 2.82222222222 <<
# >> Type of Kernel  linear <<
# 0.5 0.948275862069
# >> Type of Kernel  rbf <<
# 0.5 0.793103448276
# >> Type of Kernel  sigmoid <<
# 0.5 0.672413793103
# >> Penalty parameter C 3.36666666667 <<
# >> Type of Kernel  linear <<
# 0.5 0.98275862069
# >> Type of Kernel  rbf <<
# 0.5 0.810344827586
# >> Type of Kernel  sigmoid <<
# 0.5 0.706896551724
# >> Penalty parameter C 3.91111111111 <<
# >> Type of Kernel  linear <<
# 0.5 0.98275862069
# >> Type of Kernel  rbf <<
# 0.5 0.862068965517
# >> Type of Kernel  sigmoid <<
# 0.5 0.706896551724
# >> Penalty parameter C 4.45555555556 <<
# >> Type of Kernel  linear <<
# 0.5 0.98275862069
# >> Type of Kernel  rbf <<
# 0.5 0.862068965517
# >> Type of Kernel  sigmoid <<
# 0.5 0.672413793103
# >> Penalty parameter C 5.0 <<
# >> Type of Kernel  linear <<
# 0.5 0.98275862069
# >> Type of Kernel  rbf <<
# 0.5 0.862068965517
# >> Type of Kernel  sigmoid <<
# 0.5 0.672413793103
# --- Fold 25 ---
# >> Penalty parameter C 0.1 <<
# >> Type of Kernel  linear <<
# 0.5 0.844827586207
# >> Type of Kernel  rbf <<
# 0.5 0.603448275862
# >> Type of Kernel  sigmoid <<
# 0.5 0.551724137931
# >> Penalty parameter C 0.644444444444 <<
# >> Type of Kernel  linear <<
# 0.5 0.896551724138
# >> Type of Kernel  rbf <<
# 0.5 0.620689655172
# >> Type of Kernel  sigmoid <<
# 0.5 0.551724137931
# >> Penalty parameter C 1.18888888889 <<
# >> Type of Kernel  linear <<
# 0.5 0.896551724138
# >> Type of Kernel  rbf <<
# 0.5 0.706896551724
# >> Type of Kernel  sigmoid <<
# 0.5 0.551724137931
# >> Penalty parameter C 1.73333333333 <<
# >> Type of Kernel  linear <<
# 0.5 0.896551724138
# >> Type of Kernel  rbf <<
# 0.5 0.741379310345
# >> Type of Kernel  sigmoid <<
# 0.5 0.637931034483
# >> Penalty parameter C 2.27777777778 <<
# >> Type of Kernel  linear <<
# 0.5 0.948275862069
# >> Type of Kernel  rbf <<
# 0.5 0.758620689655
# >> Type of Kernel  sigmoid <<
# 0.5 0.620689655172
# >> Penalty parameter C 2.82222222222 <<
# >> Type of Kernel  linear <<
# 0.5 0.931034482759
# >> Type of Kernel  rbf <<
# 0.5 0.793103448276
# >> Type of Kernel  sigmoid <<
# 0.5 0.706896551724
# >> Penalty parameter C 3.36666666667 <<
# >> Type of Kernel  linear <<
# 0.5 0.948275862069
# >> Type of Kernel  rbf <<
# 0.5 0.827586206897
# >> Type of Kernel  sigmoid <<
# 0.5 0.689655172414
# >> Penalty parameter C 3.91111111111 <<
# >> Type of Kernel  linear <<
# 1.0 0.98275862069
# >> Type of Kernel  rbf <<
# 0.5 0.862068965517
# >> Type of Kernel  sigmoid <<
# 0.5 0.689655172414
# >> Penalty parameter C 4.45555555556 <<
# >> Type of Kernel  linear <<
# 1.0 0.965517241379
# >> Type of Kernel  rbf <<
# 0.5 0.879310344828
# >> Type of Kernel  sigmoid <<
# 0.5 0.706896551724
# >> Penalty parameter C 5.0 <<
# >> Type of Kernel  linear <<
# 1.0 0.98275862069
# >> Type of Kernel  rbf <<
# 0.5 0.896551724138
# >> Type of Kernel  sigmoid <<
# 0.5 0.689655172414
# --- Fold 26 ---
# >> Penalty parameter C 0.1 <<
# >> Type of Kernel  linear <<
# 1.0 0.793103448276
# >> Type of Kernel  rbf <<
# 0.0 0.51724137931
# >> Type of Kernel  sigmoid <<
# 0.0 0.51724137931
# >> Penalty parameter C 0.644444444444 <<
# >> Type of Kernel  linear <<
# 1.0 0.896551724138
# >> Type of Kernel  rbf <<
# 0.0 0.620689655172
# >> Type of Kernel  sigmoid <<
# 0.0 0.51724137931
# >> Penalty parameter C 1.18888888889 <<
# >> Type of Kernel  linear <<
# 1.0 0.913793103448
# >> Type of Kernel  rbf <<
# 0.0 0.758620689655
# >> Type of Kernel  sigmoid <<
# 0.0 0.568965517241
# >> Penalty parameter C 1.73333333333 <<
# >> Type of Kernel  linear <<
# 1.0 0.896551724138
# >> Type of Kernel  rbf <<
# 0.0 0.758620689655
# >> Type of Kernel  sigmoid <<
# 0.0 0.568965517241
# >> Penalty parameter C 2.27777777778 <<
# >> Type of Kernel  linear <<
# 1.0 0.931034482759
# >> Type of Kernel  rbf <<
# 0.0 0.741379310345
# >> Type of Kernel  sigmoid <<
# 0.0 0.620689655172
# >> Penalty parameter C 2.82222222222 <<
# >> Type of Kernel  linear <<
# 1.0 0.948275862069
# >> Type of Kernel  rbf <<
# 1.0 0.741379310345
# >> Type of Kernel  sigmoid <<
# 0.0 0.637931034483
# >> Penalty parameter C 3.36666666667 <<
# >> Type of Kernel  linear <<
# 1.0 0.948275862069
# >> Type of Kernel  rbf <<
# 1.0 0.793103448276
# >> Type of Kernel  sigmoid <<
# 0.0 0.655172413793
# >> Penalty parameter C 3.91111111111 <<
# >> Type of Kernel  linear <<
# 1.0 0.98275862069
# >> Type of Kernel  rbf <<
# 1.0 0.810344827586
# >> Type of Kernel  sigmoid <<
# 0.0 0.724137931034
# >> Penalty parameter C 4.45555555556 <<
# >> Type of Kernel  linear <<
# 1.0 0.98275862069
# >> Type of Kernel  rbf <<
# 1.0 0.827586206897
# >> Type of Kernel  sigmoid <<
# 0.0 0.724137931034
# >> Penalty parameter C 5.0 <<
# >> Type of Kernel  linear <<
# 1.0 0.98275862069
# >> Type of Kernel  rbf <<
# 0.5 0.862068965517
# >> Type of Kernel  sigmoid <<
# 0.0 0.706896551724
# --- Fold 27 ---
# >> Penalty parameter C 0.1 <<
# >> Type of Kernel  linear <<
# 1.0 0.827586206897
# >> Type of Kernel  rbf <<
# 0.5 0.586206896552
# >> Type of Kernel  sigmoid <<
# 0.5 0.551724137931
# >> Penalty parameter C 0.644444444444 <<
# >> Type of Kernel  linear <<
# 1.0 0.896551724138
# >> Type of Kernel  rbf <<
# 0.5 0.603448275862
# >> Type of Kernel  sigmoid <<
# 0.5 0.551724137931
# >> Penalty parameter C 1.18888888889 <<
# >> Type of Kernel  linear <<
# 1.0 0.879310344828
# >> Type of Kernel  rbf <<
# 1.0 0.689655172414
# >> Type of Kernel  sigmoid <<
# 0.5 0.551724137931
# >> Penalty parameter C 1.73333333333 <<
# >> Type of Kernel  linear <<
# 1.0 0.948275862069
# >> Type of Kernel  rbf <<
# 1.0 0.724137931034
# >> Type of Kernel  sigmoid <<
# 0.5 0.551724137931
# >> Penalty parameter C 2.27777777778 <<
# >> Type of Kernel  linear <<
# 1.0 0.948275862069
# >> Type of Kernel  rbf <<
# 1.0 0.741379310345
# >> Type of Kernel  sigmoid <<
# 0.5 0.568965517241
# >> Penalty parameter C 2.82222222222 <<
# >> Type of Kernel  linear <<
# 1.0 0.948275862069
# >> Type of Kernel  rbf <<
# 1.0 0.775862068966
# >> Type of Kernel  sigmoid <<
# 0.5 0.637931034483
# >> Penalty parameter C 3.36666666667 <<
# >> Type of Kernel  linear <<
# 1.0 0.948275862069
# >> Type of Kernel  rbf <<
# 1.0 0.793103448276
# >> Type of Kernel  sigmoid <<
# 0.5 0.672413793103
# >> Penalty parameter C 3.91111111111 <<
# >> Type of Kernel  linear <<
# 1.0 0.965517241379
# >> Type of Kernel  rbf <<
# 1.0 0.793103448276
# >> Type of Kernel  sigmoid <<
# 1.0 0.672413793103
# >> Penalty parameter C 4.45555555556 <<
# >> Type of Kernel  linear <<
# 1.0 0.965517241379
# >> Type of Kernel  rbf <<
# 1.0 0.810344827586
# >> Type of Kernel  sigmoid <<
# 1.0 0.689655172414
# >> Penalty parameter C 5.0 <<
# >> Type of Kernel  linear <<
# 1.0 0.98275862069
# >> Type of Kernel  rbf <<
# 1.0 0.862068965517
# >> Type of Kernel  sigmoid <<
# 1.0 0.689655172414
# --- Fold 28 ---
# >> Penalty parameter C 0.1 <<
# >> Type of Kernel  linear <<
# 0.5 0.793103448276
# >> Type of Kernel  rbf <<
# 0.5 0.603448275862
# >> Type of Kernel  sigmoid <<
# 0.5 0.620689655172
# >> Penalty parameter C 0.644444444444 <<
# >> Type of Kernel  linear <<
# 0.5 0.862068965517
# >> Type of Kernel  rbf <<
# 0.5 0.637931034483
# >> Type of Kernel  sigmoid <<
# 0.5 0.620689655172
# >> Penalty parameter C 1.18888888889 <<
# >> Type of Kernel  linear <<
# 0.5 0.896551724138
# >> Type of Kernel  rbf <<
# 0.5 0.706896551724
# >> Type of Kernel  sigmoid <<
# 0.5 0.620689655172
# >> Penalty parameter C 1.73333333333 <<
# >> Type of Kernel  linear <<
# 0.5 0.931034482759
# >> Type of Kernel  rbf <<
# 0.5 0.741379310345
# >> Type of Kernel  sigmoid <<
# 0.5 0.672413793103
# >> Penalty parameter C 2.27777777778 <<
# >> Type of Kernel  linear <<
# 0.5 0.948275862069
# >> Type of Kernel  rbf <<
# 0.5 0.741379310345
# >> Type of Kernel  sigmoid <<
# 0.5 0.672413793103
# >> Penalty parameter C 2.82222222222 <<
# >> Type of Kernel  linear <<
# 0.5 0.965517241379
# >> Type of Kernel  rbf <<
# 0.5 0.793103448276
# >> Type of Kernel  sigmoid <<
# 0.5 0.655172413793
# >> Penalty parameter C 3.36666666667 <<
# >> Type of Kernel  linear <<
# 0.5 0.965517241379
# >> Type of Kernel  rbf <<
# 0.5 0.827586206897
# >> Type of Kernel  sigmoid <<
# 0.5 0.672413793103
# >> Penalty parameter C 3.91111111111 <<
# >> Type of Kernel  linear <<
# 0.5 0.965517241379
# >> Type of Kernel  rbf <<
# 0.5 0.827586206897
# >> Type of Kernel  sigmoid <<
# 0.5 0.655172413793
# >> Penalty parameter C 4.45555555556 <<
# >> Type of Kernel  linear <<
# 0.5 0.965517241379
# >> Type of Kernel  rbf <<
# 0.5 0.844827586207
# >> Type of Kernel  sigmoid <<
# 0.5 0.689655172414
# >> Penalty parameter C 5.0 <<
# >> Type of Kernel  linear <<
# 0.5 0.965517241379
# >> Type of Kernel  rbf <<
# 0.5 0.844827586207
# >> Type of Kernel  sigmoid <<
# 0.5 0.672413793103
# --- Fold 29 ---
# >> Penalty parameter C 0.1 <<
# >> Type of Kernel  linear <<
# 0.5 0.793103448276
# >> Type of Kernel  rbf <<
# 0.5 0.603448275862
# >> Type of Kernel  sigmoid <<
# 0.5 0.568965517241
# >> Penalty parameter C 0.644444444444 <<
# >> Type of Kernel  linear <<
# 0.5 0.913793103448
# >> Type of Kernel  rbf <<
# 0.5 0.620689655172
# >> Type of Kernel  sigmoid <<
# 0.5 0.568965517241
# >> Penalty parameter C 1.18888888889 <<
# >> Type of Kernel  linear <<
# 0.5 0.931034482759
# >> Type of Kernel  rbf <<
# 0.5 0.706896551724
# >> Type of Kernel  sigmoid <<
# 0.5 0.568965517241
# >> Penalty parameter C 1.73333333333 <<
# >> Type of Kernel  linear <<
# 0.5 0.931034482759
# >> Type of Kernel  rbf <<
# 0.5 0.724137931034
# >> Type of Kernel  sigmoid <<
# 0.5 0.603448275862
# >> Penalty parameter C 2.27777777778 <<
# >> Type of Kernel  linear <<
# 0.5 0.948275862069
# >> Type of Kernel  rbf <<
# 0.5 0.758620689655
# >> Type of Kernel  sigmoid <<
# 0.5 0.620689655172
# >> Penalty parameter C 2.82222222222 <<
# >> Type of Kernel  linear <<
# 0.5 0.965517241379
# >> Type of Kernel  rbf <<
# 0.5 0.758620689655
# >> Type of Kernel  sigmoid <<
# 0.5 0.689655172414
# >> Penalty parameter C 3.36666666667 <<
# >> Type of Kernel  linear <<
# 0.5 0.965517241379
# >> Type of Kernel  rbf <<
# 0.5 0.793103448276
# >> Type of Kernel  sigmoid <<
# 0.5 0.637931034483
# >> Penalty parameter C 3.91111111111 <<
# >> Type of Kernel  linear <<
# 0.5 0.965517241379
# >> Type of Kernel  rbf <<
# 0.5 0.827586206897
# >> Type of Kernel  sigmoid <<
# 0.5 0.655172413793
# >> Penalty parameter C 4.45555555556 <<
# >> Type of Kernel  linear <<
# 0.5 0.98275862069
# >> Type of Kernel  rbf <<
# 0.5 0.862068965517
# >> Type of Kernel  sigmoid <<
# 0.5 0.672413793103
# >> Penalty parameter C 5.0 <<
# >> Type of Kernel  linear <<
# 1.0 0.98275862069
# >> Type of Kernel  rbf <<
# 0.5 0.879310344828
# >> Type of Kernel  sigmoid <<
# 0.5 0.672413793103
# Best accuracy test = 0.733333333333 Penalty parameter= 5.0 kernel type= linear
# Corresponding accuracy train = 0.979885057471

# %%
best_C=0.1;
best_kernel_type= best_kernel_type
print(train_TX.shape[0])
# Out:
# 780

# %%
from sklearn import svm
best_C=best_C;
seed=np.random.rand()
best_kernel_type=best_kernel_type
dataset_length=train_TX.shape[0];

for single_seed in seed:
    [i1,i2]=split_matrix_two_blocks(train_TX,0.7,0.3,single_seed)
    train=train_TX[i1,:]
    labels_train=labels[i1]
    test= train_TX[i2,:]
    labels_test=labels[i2]
    clf = svm.SVC(C=best_C, cache_size=200, class_weight=None, coef0=0.0,
            decision_function_shape='ovr', degree=3, gamma='auto', kernel=best_kernel_type,
            max_iter=-1, probability=False, random_state=None, shrinking=True,
            tol=0.001, verbose=False)
    clf.fit(train, labels_train)  
    predicted_labels= clf.predict(test)


    SVM_accuracy=get_accuracy(predicted_labels, labels_test)
    print(SVM_accuracy)
# Out:
# 60
# 0.666666666667
# 60
# 0.833333333333
# 60
# 0.722222222222
# 60
# 0.666666666667
# 60
# 0.777777777778
# 60
# 0.722222222222
# 60
# 0.777777777778
# 60
# 0.388888888889
# 60
# 0.777777777778
# 60
# 0.666666666667
# 60
# 0.611111111111
# 60
# 0.611111111111
# 60
# 0.666666666667
# 60
# 0.833333333333
# 60
# 0.833333333333
# 60
# 0.611111111111
# 60
# 0.777777777778
# 60
# 0.722222222222
# 60
# 0.611111111111
# 60
# 0.666666666667
# 60
# 0.722222222222
# 60
# 0.555555555556

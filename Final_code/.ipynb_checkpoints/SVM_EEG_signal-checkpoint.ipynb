# %%
import scipy.io as sio
import matplotlib.pyplot as plt
import numpy as np
from sklearn import linear_model, neighbors,datasets
from lib.helpers import *
from sklearn import svm
from lib.cross_validations_lib import *
#import peakutils
import scipy.signal as signal
import numpy as np
from sklearn.decomposition import PCA
from sklearn.cluster import MeanShift, estimate_bandwidth

# %% [markdown]
# ## Utility functions

# %%
def split_matrix_two_blocks(y, percentage1, percentage2, seed):
    """Build k indices for k-fold."""
    if(percentage1+percentage2==1):
        num_row = len(y)
        #print(num_row)
        interval_1 = int(percentage1*num_row);
        
        np.random.seed(seed)
        indices = np.random.permutation(num_row);
        first_indices = indices[0:interval_1];
        second_indices = indices[interval_1:num_row];
        return [np.array(first_indices),np.array(second_indices)]
    else:
        print('>>>>>>>>>>>ERROR:Not valid splitting percentage')
        
        
##
## This function reutrn a list of matrices. Each matrix correspond to a question instance in which each row is a channel, and in the coloumn it develop the signal in time
## The function also manage to standardize the time length
def channels_to_vector(channels): 
    time_instances=[];
    dim=channels.shape;
    #find the length min of the signal in the specified temporal instance
    length_min=len(channels[0,1]);
    for i in range (0,dim[1]):
        single_measurement=channels[0,i];
        single_length=single_measurement.shape[0]
        if(single_length<length_min):
                length_min=single_length;
    #export the signals
    for i in range (0,dim[1]):
        single_measurement=channels[0,i];
        dim1=single_measurement.shape;
        time_instance=[];
        for j  in range (0,dim1[1]):
            if(len(single_measurement[:,j])>length_min):
                single_signal=single_measurement[:,j][0:length_min]
            else:
                single_signal=single_measurement[:,j]
            #put in a list 
            time_instance.append(np.asarray(single_signal).reshape(len(single_signal),1).T);
       # create the matrix of the signals per a single time instance 
        time_instance=np.concatenate(time_instance);
        time_instances.append(time_instance);   
    return time_instances;


##
# Create the train data matrix
##
## usage
def get_feature_matrix_and_labels(channel_structure,label,features_extracted,connectivity_feature):
    list_train=[]
    list_labels=[]
    cont=0;
    index_connectivity=0;
    list_row=[]
    
    for time_instance in channel_structure:
        dim1=time_instance.shape
        #indipendent_components=extract_ICs(time_instance,n_ICA_components);
        for j  in range (0,dim1[0]):
           
            features=features_extracted[cont,:];
            list_row.append(features);
            cont=cont+1;
        """feature_dictionary["fft_max_frequencies"]=0;
        for single_component in indipendent_components:
            features=feature_extraction(single_component,feature_dictionary,features_extracted)
            list_row.append(features);"""
        list_row.append(connectivity_feature[index_connectivity,:]);
        index_connectivity=index_connectivity+1;
        labels=get_labels(1,label);
        feature_row=np.concatenate(list_row);
        list_train.append(feature_row.reshape(len(feature_row),1).T)
        list_labels.append(labels);
        list_row=[]
        
    train_TX=np.concatenate(list_train)
    labels=np.concatenate(list_labels,axis=0)
    
    return train_TX,labels.T.reshape(labels.size)


### Description
def get_labels(number, string):
    if(string=="No"):
        return np.zeros(number)    
    if(string=="Yes"):
        return np.ones(number)
    
## description
def select_features(weights,matrix,th):
    cont=0;
    i=0;
    while(cont<len(weights)):
        if(weights[cont]<th):

            mask = np.ones(matrix.shape[1], dtype=bool)
            mask[i] = False
            matrix=matrix[:,mask]
        else:
            i=i+1;
        cont=cont+1;
    return matrix

# %% [markdown]
# # EEG feature loading
# Import data from previous analysis

# %%
#Import data from mat files
yes_EEG_contents = sio.loadmat('EEGyes.mat')
no_EEG_contents = sio.loadmat('EEGno.mat')

channels_no_EEG=no_EEG_contents["EEGno"]
channels_yes_EEG=yes_EEG_contents["EEGyes"]

#Features Loading
features_extracted_yes   = sio.loadmat('FeaturesYes.mat')['FeaturesYes']
features_extracted_no    = sio.loadmat('FeaturesNO.mat')['FeaturesNo']
connectivity_feature_yes = sio.loadmat('ConnectivityFeaturesYes.mat')['ConnectivityFeaturesYes']
connectivity_feature_no  = sio.loadmat('ConnectivityFeaturesNo.mat')['ConnectivityFeaturesNo']

channels_structure_yes_EEG = channels_to_vector(channels_yes_EEG)
channels_structure_no_EEG  = channels_to_vector(channels_no_EEG)

##Structuring of the data:
#the code below create the train matrix with respect to the signal given in "channel_structure" but using the features contained in "features_extracted*" and in "connettivity_feature*".
feature_dataset_yes_EEG, EEG_yes_labels = get_feature_matrix_and_labels(channels_structure_yes_EEG,"Yes",features_extracted_yes,connectivity_feature_yes);

feature_dataset_no_EEG, EEG_no_labels = get_feature_matrix_and_labels(channels_structure_no_EEG,"No",features_extracted_no,connectivity_feature_no);

#Merge the labeled data
feature_dataset_full = np.concatenate((feature_dataset_yes_EEG, feature_dataset_no_EEG), axis=0 )
labels = np.concatenate((EEG_yes_labels,EEG_no_labels), axis=0)


print("The dataset have shape:")
print(feature_dataset_full.shape)
# Out:
# The dataset have shape:
# (60, 386)

# %% [markdown]
# # Best feature selection
#
# ## ANOVA F-value
#
# Here we have built a function that:
#
# 1) select the best set of k (k given in input) features using ANOVA F-Test (credits to the scikit learn implentation)
#
# 2) perform a selection of the best hyperparameters for the SVM with a validation accuracy estimation done with k-cross.
#
#     a) Search of the best C in a logartimic grid and the best kernels between linear, rbf and sigmoid
#
#     b) Search of the best C in a linear grid (keeping the best kernel of point a)
#
# 3) Performance evaluation of the model over different train/test fractions, evaluated num_experiment times and averaged

# %%
from sklearn import svm
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif

def hyper_SVM_multiple_executions(X, Y, C_parameters, kernel_types, max_iters, fraction_train_test, num_experiments):
    
    accuracies_train = np.zeros([len(C_parameters),len(kernel_types)])
    accuracies_test = np.zeros([len(C_parameters),len(kernel_types)])
    svm_total_acc_test = []
    svm_total_acc_train = []
    seed=np.arange(num_experiments, dtype = 'int64')
    # For each degree, compute the least squares weights, the predictions and the accuracies
    #print(num_experiments)
    #print(seed)
        
        
    for C_id, single_C in enumerate(C_parameters):
                
        #print('>> Penalty parameter C', single_C, '<<')
                
        for kernel_id, single_kernel in enumerate(kernel_types):
            #print('>> Type of Kernel ',single_kernel, '<')
            # Compute the best weights on the training set
                for single_seed in seed:
                    [i1,i2]=split_matrix_two_blocks(X, fraction_train_test, 1-fraction_train_test,single_seed)
                    #print(seed)
                    #print(i2)
                    train=X[i1,:]
                    labels_train=Y[i1]

                    test= X[i2,:]
                    labels_test=Y[i2]

                    #SVM classifier definition
                    clf = svm.SVC(C=single_C, cache_size=200, class_weight=None, coef0=0.0,
        decision_function_shape='ovr', degree=3, gamma='auto', kernel=single_kernel,
        max_iter=max_iters, probability=False, random_state=None, shrinking=True,
        tol=0.001, verbose=False)
                    #SVM fit on train data
                    clf.fit(train, labels_train)  


                    #Accuracy on test
                    predicted_labels_test = clf.predict(test)
                    SVM_accuracy_test = get_accuracy(predicted_labels_test, labels_test)
                    svm_total_acc_test.append(SVM_accuracy_test)


                    #Accuracy on train
                    predicted_labels_train = clf.predict(train)
                    SVM_accuracy_train = get_accuracy(predicted_labels_train, labels_train)
                    svm_total_acc_train.append(SVM_accuracy_train)

                
    


         
                # Compute the accuracies for each degree
                accuracies_train[C_id,kernel_id] = np.mean(svm_total_acc_train)
                accuracies_test[C_id,kernel_id] = np.mean(svm_total_acc_test)
            #print(accuracies_test[C_id,kernel_id],accuracies_train[C_id,kernel_id])
        
        
    return accuracies_train, accuracies_test



def tuning_SVM(X, Y, C_parameters, kernel_types, max_iters, fraction_train_test, num_experiments):
    
    
    # Initialize matrix of computed accuracies for each degree and each fold
    #accuracies_train_by_fold = np.zeros([len(C_parameters), len(kernel_types)])
    #accuracies_test_by_fold = np.zeros([len(C_parameters), len(kernel_types)])
    
       
    # Compute the accuracies for each degree
    accuracies_train, accuracies_test =  hyper_SVM_multiple_executions(X, Y, C_parameters, kernel_types, max_iters, fraction_train_test, num_experiments)
    
    # Get the index of the best accuracy in the testing set
    max_id_C_parameter, max_id_kernel= \
        np.unravel_index(accuracies_test.argmax(), accuracies_test.shape)
    
    # Find the optimal degree and the corresponding accuracies in the training and testing sets
    best_C_parameter=C_parameters[max_id_C_parameter]
    best_kernel_type=kernel_types[max_id_kernel]
    best_accuracy_test = accuracies_test[max_id_C_parameter,max_id_kernel]
    corresponding_accuracy_train = accuracies_train[max_id_C_parameter,max_id_kernel]
    
    #print('Best accuracy test =', best_accuracy_test , 'Penalty parameter=',best_C_parameter, 'kernel type=',best_kernel_type)
    #print('Corresponding accuracy train =', corresponding_accuracy_train)
    
    return best_C_parameter, best_kernel_type, best_accuracy_test, corresponding_accuracy_train


def classification_SVM_experiments(X, Y, best_C_input, best_kernel_type, fraction_train_test, num_experiments):
 
    best_C=best_C_input
    seed=range(num_experiments)
    svm_total_acc_test  = []
    svm_total_acc_train = [] 
    best_kernel_type=best_kernel_type
    dataset_length=X.shape[0];
    
    
    for single_seed in seed:
        [i1,i2]=split_matrix_two_blocks(X, fraction_train_test, 1-fraction_train_test,single_seed)
        
        train=X[i1,:]
        labels_train=Y[i1]
        
        test= X[i2,:]
        labels_test=Y[i2]

        #SVM classifier definition
        clf = svm.SVC(C=best_C, cache_size=200, class_weight=None, coef0=0.0,
                decision_function_shape='ovr', degree=3, gamma='auto', kernel=best_kernel_type,
                max_iter=100, probability=False, random_state=None, shrinking=True,
                tol=0.001, verbose=False)
        #SVM fit on train data
        clf.fit(train, labels_train)  
        
        
        #Accuracy on test
        predicted_labels_test = clf.predict(test)
        SVM_accuracy_test = get_accuracy(predicted_labels_test, labels_test)
        svm_total_acc_test.append(SVM_accuracy_test)
        
        
        #Accuracy on train
        predicted_labels_train = clf.predict(train)
        SVM_accuracy_train = get_accuracy(predicted_labels_train, labels_train)
        svm_total_acc_train.append(SVM_accuracy_train)
        #print("Accuracy: "+ str(SVM_accuracy) + "; iteration  " + str(single_seed) )
    return svm_total_acc_test, svm_total_acc_train

def performance_tuning_k(X, Y, k, num_experiment_final = 10, num_experiment_hyper = 10):
    feature_dataset_full = X
    labels = Y
    reducer = SelectKBest(f_classif, k)
    feature_dataset_reduced = reducer.fit_transform(feature_dataset_full, labels)

    boolean_vec = reducer.get_support()
    idx_features =[]
    for i in range(len(boolean_vec)): 
        if boolean_vec[i] == True: idx_features.append(i)
    
    #print("index of features retained:")
    #print(idx)

    #hyperparameters tune 1
    C_parameters= np.logspace(-6, 3, 100)
    k_fold = 5 # number of k sub-folders to divide the set
    seed = 1
    max_iters = 100
    kernel_types=['linear', 'rbf', 'sigmoid']
    
    
    best_C, best_kernel_type, best_accuracy_test, corresponding_accuracy_train = tuning_SVM(feature_dataset_reduced, labels, C_parameters, kernel_types, max_iters, 0.7, num_experiment_hyper)


    #hyperparameters tune 2
    C_param_sophisticated = np.linspace(best_C/10,best_C*10,100)
    kernel_types_reasonable = [best_kernel_type]
    
    
    best_C, best_kernel_type, best_accuracy_test, corresponding_accuracy_train = tuning_SVM(feature_dataset_reduced, labels, C_param_sophisticated, kernel_types_reasonable, max_iters, 0.7, num_experiment_hyper)


    #performances assessment

    acc_test, acc_train = classification_SVM_experiments(feature_dataset_reduced, labels, best_C, best_kernel_type, 0.7, num_experiment_final)
        #saving of metrics of interest
    return [np.mean(acc_test), np.std(acc_test), idx_features]

import time
def best_subset_selection(X,Y, num_features_max):
    mean_test = []
    std_test = []
    idx_features_all = []
    for k in range(1, num_features_max):
        before = time.time()
        print("progress: " + str(int(k/num_features_max * 100)) + " %")
        [test, std, idx_features] = performance_tuning_k(X, Y, k)
        mean_test.append(test)
        std_test.append(std)
        idx_features_all.append(idx_features)
        print("accuracy on validation set with k = " + str(k) + " is " + str(test))
        print("time passed = " + str(time.time()-before))

        
        
    k_best_idx = np.argmax(mean_test)
    k_best = k_best_idx+1 #because index start from 0
    print("The best k is: " + str(k_best))
    print("Mean test validation performances: " + str(mean_test[k_best_idx]))
    return k_best, mean_test[k_best_idx], std_test[k_best_idx], idx_features_all[k_best_idx]

# %%
import time
bef = time.time()
[k_best, test_perf, std_perf, idx_feat] = best_subset_selection(feature_dataset_full, labels, 120)
print(str(time.time()-bef))
# Out:
# progress: 0 %
# /anaconda/lib/python3.6/site-packages/sklearn/utils/__init__.py:54: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(mask.dtype, np.int):
# /anaconda/lib/python3.6/site-packages/sklearn/svm/base.py:220: ConvergenceWarning: Solver terminated early (max_iter=100).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# accuracy on validation set with k = 1 is 0.7111111111111111
# time passed = 5.5134241580963135
# progress: 1 %
# accuracy on validation set with k = 2 is 0.7166666666666667
# time passed = 5.714189052581787
# progress: 2 %
# accuracy on validation set with k = 3 is 0.7722222222222221
# time passed = 5.867809772491455
# progress: 3 %
# accuracy on validation set with k = 4 is 0.7722222222222221
# time passed = 5.754342079162598
# progress: 4 %
# accuracy on validation set with k = 5 is 0.7944444444444445
# time passed = 5.328441858291626
# progress: 5 %
# accuracy on validation set with k = 6 is 0.7833333333333333
# time passed = 5.645567893981934
# progress: 5 %
# accuracy on validation set with k = 7 is 0.7722222222222221
# time passed = 5.543716907501221
# progress: 6 %
# accuracy on validation set with k = 8 is 0.5444444444444445
# time passed = 5.491635322570801
# progress: 7 %
# accuracy on validation set with k = 9 is 0.6222222222222222
# time passed = 5.294245004653931
# progress: 8 %
# accuracy on validation set with k = 10 is 0.6055555555555556
# time passed = 5.734766006469727
# progress: 9 %
# accuracy on validation set with k = 11 is 0.6388888888888888
# time passed = 5.623941898345947
# progress: 10 %
# accuracy on validation set with k = 12 is 0.6611111111111111
# time passed = 5.738525152206421
# progress: 10 %
# accuracy on validation set with k = 13 is 0.6555555555555556
# time passed = 5.701128959655762
# progress: 11 %
# accuracy on validation set with k = 14 is 0.6777777777777777
# time passed = 5.299061059951782
# progress: 12 %
# accuracy on validation set with k = 15 is 0.6722222222222222
# time passed = 5.114896059036255
# progress: 13 %
# accuracy on validation set with k = 16 is 0.6666666666666667
# time passed = 5.368269920349121
# progress: 14 %
# accuracy on validation set with k = 17 is 0.6666666666666667
# time passed = 5.334517002105713
# progress: 15 %
# accuracy on validation set with k = 18 is 0.65
# time passed = 5.241765737533569
# progress: 15 %
# accuracy on validation set with k = 19 is 0.65
# time passed = 5.501008033752441
# progress: 16 %
# accuracy on validation set with k = 20 is 0.6555555555555556
# time passed = 5.296703100204468
# progress: 17 %
# accuracy on validation set with k = 21 is 0.7333333333333334
# time passed = 5.345614671707153
# progress: 18 %
# accuracy on validation set with k = 22 is 0.75
# time passed = 5.371511936187744
# progress: 19 %
# accuracy on validation set with k = 23 is 0.6833333333333333
# time passed = 5.507797002792358
# progress: 20 %
# accuracy on validation set with k = 24 is 0.6888888888888889
# time passed = 6.577337980270386
# progress: 20 %
# accuracy on validation set with k = 25 is 0.7111111111111111
# time passed = 6.5388710498809814
# progress: 21 %
# accuracy on validation set with k = 26 is 0.7166666666666667
# time passed = 6.777801275253296
# progress: 22 %
# accuracy on validation set with k = 27 is 0.7166666666666667
# time passed = 5.877601861953735
# progress: 23 %
# accuracy on validation set with k = 28 is 0.7222222222222222
# time passed = 7.322756052017212
# progress: 24 %
# accuracy on validation set with k = 29 is 0.7111111111111111
# time passed = 6.332610845565796
# progress: 25 %
# accuracy on validation set with k = 30 is 0.7166666666666667
# time passed = 5.59434700012207
# progress: 25 %
# accuracy on validation set with k = 31 is 0.8111111111111111
# time passed = 7.958345890045166
# progress: 26 %
# accuracy on validation set with k = 32 is 0.8277777777777778
# time passed = 7.0569610595703125
# progress: 27 %
# accuracy on validation set with k = 33 is 0.7166666666666667
# time passed = 6.259992837905884
# progress: 28 %
# accuracy on validation set with k = 34 is 0.7555555555555555
# time passed = 6.139992952346802
# progress: 29 %
# accuracy on validation set with k = 35 is 0.7666666666666667
# time passed = 6.708945989608765
# progress: 30 %
# accuracy on validation set with k = 36 is 0.8055555555555556
# time passed = 6.565541982650757
# progress: 30 %
# accuracy on validation set with k = 37 is 0.8222222222222222
# time passed = 5.774931192398071
# progress: 31 %
# accuracy on validation set with k = 38 is 0.7166666666666667
# time passed = 5.806376934051514
# progress: 32 %
# accuracy on validation set with k = 39 is 0.711111111111111
# time passed = 5.690320014953613
# progress: 33 %
# accuracy on validation set with k = 40 is 0.7388888888888889
# time passed = 5.79902720451355
# progress: 34 %
# accuracy on validation set with k = 41 is 0.7222222222222222
# time passed = 5.64408802986145
# progress: 35 %
# accuracy on validation set with k = 42 is 0.7166666666666667
# time passed = 5.718387842178345
# progress: 35 %
# accuracy on validation set with k = 43 is 0.7333333333333333
# time passed = 5.792192697525024
# progress: 36 %
# accuracy on validation set with k = 44 is 0.7111111111111111
# time passed = 5.935351848602295
# progress: 37 %
# accuracy on validation set with k = 45 is 0.7166666666666667
# time passed = 5.845432996749878
# progress: 38 %
# accuracy on validation set with k = 46 is 0.6944444444444444
# time passed = 5.78810977935791
# progress: 39 %
# accuracy on validation set with k = 47 is 0.7611111111111111
# time passed = 5.908524036407471
# progress: 40 %
# accuracy on validation set with k = 48 is 0.7333333333333332
# time passed = 5.987779855728149
# progress: 40 %
# accuracy on validation set with k = 49 is 0.7166666666666666
# time passed = 5.884908199310303
# progress: 41 %
# accuracy on validation set with k = 50 is 0.8222222222222222
# time passed = 5.894438743591309
# progress: 42 %
# accuracy on validation set with k = 51 is 0.7833333333333333
# time passed = 5.885771036148071
# progress: 43 %
# accuracy on validation set with k = 52 is 0.7611111111111111
# time passed = 5.933305978775024
# progress: 44 %
# accuracy on validation set with k = 53 is 0.7777777777777778
# time passed = 5.903670072555542
# progress: 45 %
# accuracy on validation set with k = 54 is 0.8111111111111111
# time passed = 5.929743051528931
# progress: 45 %
# accuracy on validation set with k = 55 is 0.7388888888888888
# time passed = 5.932062864303589
# progress: 46 %
# accuracy on validation set with k = 56 is 0.8055555555555556
# time passed = 5.987727165222168
# progress: 47 %
# accuracy on validation set with k = 57 is 0.8277777777777777
# time passed = 5.9440178871154785
# progress: 48 %
# accuracy on validation set with k = 58 is 0.7944444444444444
# time passed = 6.066977024078369
# progress: 49 %
# accuracy on validation set with k = 59 is 0.7611111111111112
# time passed = 5.922332048416138
# progress: 50 %
# accuracy on validation set with k = 60 is 0.7833333333333333
# time passed = 6.227401971817017
# progress: 50 %
# accuracy on validation set with k = 61 is 0.8166666666666668
# time passed = 5.954908132553101
# progress: 51 %
# accuracy on validation set with k = 62 is 0.8444444444444444
# time passed = 5.931251049041748
# progress: 52 %
# accuracy on validation set with k = 63 is 0.8388888888888889
# time passed = 5.997797012329102
# progress: 53 %
# accuracy on validation set with k = 64 is 0.7888888888888889
# time passed = 5.889564037322998
# progress: 54 %
# accuracy on validation set with k = 65 is 0.7388888888888889
# time passed = 6.140037775039673
# progress: 55 %
# accuracy on validation set with k = 66 is 0.7388888888888889
# time passed = 5.948210954666138
# progress: 55 %
# accuracy on validation set with k = 67 is 0.7666666666666666
# time passed = 6.03339695930481
# progress: 56 %
# accuracy on validation set with k = 68 is 0.7888888888888889
# time passed = 6.0813539028167725
# progress: 57 %
# accuracy on validation set with k = 69 is 0.7722222222222224
# time passed = 6.152303695678711
# progress: 58 %
# accuracy on validation set with k = 70 is 0.788888888888889
# time passed = 5.958522081375122
# progress: 59 %
# accuracy on validation set with k = 71 is 0.7499999999999999
# time passed = 6.029911994934082
# progress: 60 %
# accuracy on validation set with k = 72 is 0.8222222222222222
# time passed = 6.095027923583984
# progress: 60 %
# accuracy on validation set with k = 73 is 0.8111111111111111
# time passed = 6.146038055419922
# progress: 61 %
# accuracy on validation set with k = 74 is 0.7611111111111112
# time passed = 6.083868980407715
# progress: 62 %
# accuracy on validation set with k = 75 is 0.7555555555555556
# time passed = 6.181195974349976
# progress: 63 %
# accuracy on validation set with k = 76 is 0.8444444444444444
# time passed = 6.518031120300293
# progress: 64 %
# accuracy on validation set with k = 77 is 0.8
# time passed = 6.118474006652832
# progress: 65 %
# accuracy on validation set with k = 78 is 0.7722222222222224
# time passed = 6.479090213775635
# progress: 65 %
# accuracy on validation set with k = 79 is 0.7444444444444445
# time passed = 6.293274879455566
# progress: 66 %
# accuracy on validation set with k = 80 is 0.8111111111111111
# time passed = 6.178763151168823
# progress: 67 %
# accuracy on validation set with k = 81 is 0.788888888888889
# time passed = 6.253147125244141
# progress: 68 %
# accuracy on validation set with k = 82 is 0.7722222222222223
# time passed = 6.229018211364746
# progress: 69 %
# accuracy on validation set with k = 83 is 0.7277777777777777
# time passed = 6.266086101531982
# progress: 70 %
# accuracy on validation set with k = 84 is 0.7222222222222222
# time passed = 6.458822965621948
# progress: 70 %
# accuracy on validation set with k = 85 is 0.7722222222222224
# time passed = 6.339139223098755
# progress: 71 %
# accuracy on validation set with k = 86 is 0.7611111111111112
# time passed = 6.307682037353516
# progress: 72 %
# accuracy on validation set with k = 87 is 0.7611111111111111
# time passed = 6.3188982009887695
# progress: 73 %
# accuracy on validation set with k = 88 is 0.8277777777777778
# time passed = 6.251121282577515
# progress: 74 %
# accuracy on validation set with k = 89 is 0.8333333333333333
# time passed = 6.285197973251343
# progress: 75 %
# accuracy on validation set with k = 90 is 0.7388888888888889
# time passed = 6.868222951889038
# progress: 75 %
# accuracy on validation set with k = 91 is 0.85
# time passed = 6.629191875457764
# progress: 76 %
# accuracy on validation set with k = 92 is 0.8388888888888889
# time passed = 6.431596994400024
# progress: 77 %
# accuracy on validation set with k = 93 is 0.8277777777777778
# time passed = 6.595071792602539
# progress: 78 %
# accuracy on validation set with k = 94 is 0.8
# time passed = 6.5951831340789795
# progress: 79 %
# accuracy on validation set with k = 95 is 0.8055555555555556
# time passed = 6.622282981872559
# progress: 80 %
# accuracy on validation set with k = 96 is 0.8277777777777778
# time passed = 6.911375999450684
# progress: 80 %
# accuracy on validation set with k = 97 is 0.7944444444444445
# time passed = 6.583549976348877
# progress: 81 %
# accuracy on validation set with k = 98 is 0.7944444444444445
# time passed = 7.153795957565308
# progress: 82 %
# accuracy on validation set with k = 99 is 0.7944444444444445
# time passed = 7.56016206741333
# progress: 83 %
# accuracy on validation set with k = 100 is 0.788888888888889
# time passed = 7.436251163482666
# progress: 84 %
# accuracy on validation set with k = 101 is 0.7666666666666667
# time passed = 7.651124954223633
# progress: 85 %
# accuracy on validation set with k = 102 is 0.7222222222222221
# time passed = 6.919348955154419
# progress: 85 %
# accuracy on validation set with k = 103 is 0.7166666666666667
# time passed = 7.56572413444519
# progress: 86 %
# accuracy on validation set with k = 104 is 0.7833333333333334
# time passed = 6.087710857391357
# progress: 87 %
# accuracy on validation set with k = 105 is 0.7722222222222221
# time passed = 5.9131059646606445
# progress: 88 %
# accuracy on validation set with k = 106 is 0.7333333333333334
# time passed = 5.995846271514893
# progress: 89 %
# accuracy on validation set with k = 107 is 0.7222222222222222
# time passed = 5.871757984161377
# progress: 90 %
# accuracy on validation set with k = 108 is 0.7166666666666666
# time passed = 5.988616943359375
# progress: 90 %
# accuracy on validation set with k = 109 is 0.7611111111111111
# time passed = 5.871981859207153
# progress: 91 %
# accuracy on validation set with k = 110 is 0.7333333333333334
# time passed = 6.000941753387451
# progress: 92 %
# accuracy on validation set with k = 111 is 0.711111111111111
# time passed = 6.007488012313843
# progress: 93 %
# accuracy on validation set with k = 112 is 0.7777777777777778
# time passed = 6.271730899810791
# progress: 94 %
# accuracy on validation set with k = 113 is 0.6888888888888889
# time passed = 6.232882022857666
# progress: 95 %
# accuracy on validation set with k = 114 is 0.7833333333333333
# time passed = 6.1688618659973145
# progress: 95 %
# accuracy on validation set with k = 115 is 0.7388888888888889
# time passed = 6.261803150177002
# progress: 96 %
# accuracy on validation set with k = 116 is 0.7444444444444445
# time passed = 6.2652199268341064
# progress: 97 %
# accuracy on validation set with k = 117 is 0.7555555555555555
# time passed = 6.229368209838867
# progress: 98 %
# accuracy on validation set with k = 118 is 0.7611111111111111
# time passed = 6.462670087814331
# progress: 99 %
# accuracy on validation set with k = 119 is 0.75
# time passed = 6.304064035415649
# The best k is: 91
# Mean test validation performances: 0.85
# 727.6515500545502

# %% [markdown]
# ## Performance assesment of best k features with different train/test division

# %%
num_experiments_hyper = 100
fraction_train_test = 0.7

best_reduced_dataset = feature_dataset_full[:,idx_feat]
C_parameters= np.logspace(-3, 4, 100)
kernel_types=['linear', 'rbf', 'sigmoid']

print("start first tune")
best_C, best_kernel_type, best_accuracy_test, corresponding_accuracy_train = \
            tuning_SVM(best_reduced_dataset, labels, C_parameters, kernel_types, -1, fraction_train_test, num_experiments = num_experiments_hyper)

    #hyperparameters tune 2
C_param_sophisticated = np.linspace(best_C/10,best_C*10,100)
kernel_types_reasonable = [best_kernel_type]


print("start second tune")
best_C, best_kernel_type, best_accuracy_test, corresponding_accuracy_train = \
            tuning_SVM(best_reduced_dataset, labels, C_param_sophisticated, kernel_types_reasonable, -1, fraction_train_test, num_experiments = num_experiments_hyper)
    
fracs = np.linspace(0.2,0.9,20)
accuracy_test_mean  = []
accuracy_test_std   = []
accuracy_train_mean = []
accuracy_train_std  = []

for frac_tr_te in fracs:
    print(frac_tr_te)
    acc_test, acc_train = classification_SVM_experiments(best_reduced_dataset, labels, best_C, best_kernel_type, frac_tr_te, num_experiment)
    #saving of metrics of interest
    accuracy_test_mean.append(np.mean(acc_test))
    accuracy_test_std.append(np.std(acc_test))
    accuracy_train_mean.append(np.mean(acc_train))
    accuracy_train_std.append(np.std(acc_train))
# Out:
# start first tune
# start second tune
# 0.2
# /anaconda/lib/python3.6/site-packages/sklearn/svm/base.py:220: ConvergenceWarning: Solver terminated early (max_iter=100).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# 0.2368421052631579
# 0.2736842105263158
# 0.31052631578947365
# 0.34736842105263155
# 0.38421052631578945
# 0.42105263157894735
# 0.45789473684210524
# 0.49473684210526314
# 0.531578947368421
# 0.5684210526315789
# 0.6052631578947368
# 0.6421052631578947
# 0.6789473684210525
# 0.7157894736842105
# 0.7526315789473683
# 0.7894736842105263
# 0.8263157894736841
# 0.8631578947368421
# 0.9

# %% [markdown]
# ## Results plotting

# %%
print(best_C, best_kernel_type)
# Out:
# 0.01 linear

# %%
plt.errorbar(fracs, accuracy_test_mean, yerr=accuracy_test_std, label="Error bars plot", fmt="s-",  linewidth=3)
plt.errorbar(fracs, accuracy_train_mean, yerr=accuracy_train_std, label="Error bars plot", fmt="s-",  linewidth=3)
plt.title('SVM perfomances over different train/test dataset')
plt.ylabel('Accuracy')
plt.xlabel('Train/test fraction')
plt.legend(['Test Accuracy', 'Train Accuracy'], loc=4)
plt.savefig('train_test_acc', format='pdf')
plt.show()

# %% [markdown]
# # Leave One Out Validation perfomances estimate

# %%
X = best_reduced_dataset
Y = labels


svm_total_acc_test = []
#performances assessment with leave one out
for i in range(X.shape[0]):
#SVM classifier definition
    i1 = [j for j in range(60)]
    i1.remove(i)
    i2 = i
    train=X[i1,:]
    labels_train=Y[i1]

    test= X[i2,:]
    labels_test=Y[i2]
    #print(i1)
    #print(i2)
    clf = svm.SVC(C=best_C, cache_size=200, class_weight=None, coef0=0.0,
        decision_function_shape='ovr', degree=3, gamma='auto', kernel=best_kernel_type,
        max_iter=-1, probability=False, random_state=None, shrinking=True,
        tol=0.001, verbose=False)
    #SVM fit on train data
    clf.fit(train, labels_train)  

    #Accuracy on test
    predicted_labels_test = clf.predict(test)
    SVM_accuracy_test = get_accuracy(predicted_labels_test, labels_test)
    svm_total_acc_test.append(SVM_accuracy_test)


print("mean of test accuracy")
print(np.mean(svm_total_acc_test))
# Out:
# /anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# mean of test accuracy
# 0.9
# /anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)

# %%
best_C = 73.42342342342343
best_kernel_type = 'linear'
k = 92
num_experiment = 100
reducer = SelectKBest(f_classif, k)
feature_dataset_reduced = reducer.fit_transform(feature_dataset_full, labels)
fracs = np.linspace(0.2,0.9,20)
accuracy_test_mean  = []
accuracy_test_std   = []
accuracy_train_mean = []
accuracy_train_std  = []

for frac_tr_te in fracs:
    print(frac_tr_te)
    acc_test, acc_train = classification_SVM_experiments(feature_dataset_reduced, labels, best_C, best_kernel_type, frac_tr_te, num_experiment)
    #saving of metrics of interest
    accuracy_test_mean.append(np.mean(acc_test))
    accuracy_test_std.append(np.std(acc_test))
    accuracy_train_mean.append(np.mean(acc_train))
    accuracy_train_std.append(np.std(acc_train))

plt.errorbar(fracs, accuracy_test_mean, yerr=accuracy_test_std, label="Error bars plot", fmt="s-",  linewidth=3)
plt.errorbar(fracs, accuracy_train_mean, yerr=accuracy_train_std, label="Error bars plot", fmt="s-",  linewidth=3)
plt.title('SVM perfomances over different train/test dataset')
plt.ylabel('Accuracy')
plt.xlabel('Train/test fraction')
plt.legend(['Test Accuracy', 'Train Accuracy'], loc=4)
plt.savefig('train_test_acc', format='pdf')
plt.show()
# Out:
# /anaconda/lib/python3.6/site-packages/sklearn/utils/__init__.py:54: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(mask.dtype, np.int):
# /anaconda/lib/python3.6/site-packages/sklearn/svm/base.py:220: ConvergenceWarning: Solver terminated early (max_iter=100).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# 0.2
# 0.2368421052631579
# 0.2736842105263158
# 0.31052631578947365
# 0.34736842105263155
# 0.38421052631578945
# 0.42105263157894735
# 0.45789473684210524
# 0.49473684210526314
# 0.531578947368421
# 0.5684210526315789
# 0.6052631578947368
# 0.6421052631578947
# 0.6789473684210525
# 0.7157894736842105
# 0.7526315789473683
# 0.7894736842105263
# 0.8263157894736841
# 0.8631578947368421
# 0.9

# %%
best_C = 73.42342342342343
best_kernel_type = 'linear'
k = 92
num_experiment = 100
reducer = SelectKBest(f_classif, k)
feature_dataset_reduced = reducer.fit_transform(feature_dataset_full, labels)
fracs = np.linspace(0.2,0.9,20)
accuracy_test_mean  = []
accuracy_test_std   = []
accuracy_train_mean = []
accuracy_train_std  = []

for frac_tr_te in fracs:
    print(frac_tr_te)
    acc_test, acc_train = classification_SVM_experiments(feature_dataset_reduced, labels, best_C, best_kernel_type, frac_tr_te, num_experiment)
    #saving of metrics of interest
    accuracy_test_mean.append(np.mean(acc_test))
    accuracy_test_std.append(np.std(acc_test))
    accuracy_train_mean.append(np.mean(acc_train))
    accuracy_train_std.append(np.std(acc_train))

plt.errorbar(fracs, accuracy_test_mean, yerr=accuracy_test_std, label="Error bars plot", fmt="s-",  linewidth=3)
plt.errorbar(fracs, accuracy_train_mean, yerr=accuracy_train_std, label="Error bars plot", fmt="s-",  linewidth=3)
plt.title('SVM perfomances over different train/test dataset')
plt.ylabel('Accuracy')
plt.xlabel('Train/test fraction')
plt.legend(['Test Accuracy', 'Train Accuracy'], loc=4)
plt.savefig('train_test_acc', format='pdf')
plt.show()
# Out:
# /anaconda/lib/python3.6/site-packages/sklearn/utils/__init__.py:54: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(mask.dtype, np.int):
# /anaconda/lib/python3.6/site-packages/sklearn/svm/base.py:220: ConvergenceWarning: Solver terminated early (max_iter=100).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# 0.2
# 0.2368421052631579
# 0.2736842105263158
# 0.31052631578947365
# 0.34736842105263155
# 0.38421052631578945
# 0.42105263157894735
# 0.45789473684210524
# 0.49473684210526314
# 0.531578947368421
# 0.5684210526315789
# 0.6052631578947368
# 0.6421052631578947
# 0.6789473684210525
# 0.7157894736842105
# 0.7526315789473683
# 0.7894736842105263
# 0.8263157894736841
# 0.8631578947368421
# 0.9

# %%
##Feature Selection
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif


#best Values
best_C = 73.42342342342343
best_kernel_type = 'linear'
k = 92

#feature selection
reducer = SelectKBest(f_classif, k)
feature_dataset_reduced = reducer.fit_transform(feature_dataset_full, labels)

X = feature_dataset_reduced
Y = labels

boolean_vec = reducer.get_support()
idx =[]
for i in range(len(boolean_vec)): 
    if boolean_vec[i] == True: idx.append(i)
print("index of features retained:")
print(idx)
tested = np.zeros(60,60,60)
svm_total_acc_test = []
#performances assessment with leave three out
for i in range(60):
    for j in range(60):
        if(j!=i):
            for k in range(60):
                if(k!=j and k!=i):
            #SVM classifier definition
                    i1 = [l for l in range(60)]
                    i1.remove(i)
                    i1.remove(j)
                    i2 = [i, j, k]
                    
                    train=X[i1,:]
                    labels_train=Y[i1]

                    test= X[i2,:]
                    labels_test=Y[i2]
                #print(i1)
                #print(i2)
                    clf = svm.SVC(C=best_C, cache_size=200, class_weight=None, coef0=0.0,
                    decision_function_shape='ovr', degree=3, gamma='auto', kernel=best_kernel_type,
                    max_iter=-1, probability=False, random_state=None, shrinking=True,
                    tol=0.001, verbose=False)
                #SVM fit on train data
                    clf.fit(train, labels_train)  

                #Accuracy on test
                    predicted_labels_test = clf.predict(test)
                    SVM_accuracy_test = get_accuracy(predicted_labels_test, labels_test)
                    svm_total_acc_test.append(SVM_accuracy_test)


print("mean of test accuracy")
print(np.mean(svm_total_acc_test))
# Out:
# /anaconda/lib/python3.6/site-packages/sklearn/utils/__init__.py:54: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(mask.dtype, np.int):
# index of features retained:
# [3, 7, 11, 14, 18, 22, 26, 29, 35, 39, 40, 45, 46, 51, 55, 58, 62, 66, 67, 70, 71, 74, 78, 82, 83, 88, 92, 93, 96, 97, 101, 106, 110, 111, 115, 118, 119, 120, 122, 128, 134, 136, 139, 143, 149, 158, 161, 164, 165, 168, 169, 172, 173, 189, 192, 193, 201, 212, 213, 214, 216, 217, 218, 224, 228, 230, 236, 240, 244, 247, 248, 256, 260, 262, 263, 272, 276, 284, 287, 288, 291, 292, 304, 312, 316, 320, 336, 340, 354, 358, 368, 369]
# mean of test accuracy
# 0.9641242937853107

# %%
print("The evaluation of 205'320 different dataset partitions with Leave-3-out lead to an assesment of the perfomances as: \n")

print("Validation accuracy: " + str(np.mean(svm_total_acc_test)))
print("Standard deviation of the validation accuracy: " + str(np.std(svm_total_acc_test)))
print("95-percentile of the validation accuracy: " + str(1.95*np.std(svm_total_acc_test)))
# Out:
# The evaluation of 205'320 different dataset partitions with Leave-3-out lead to an assesment of the perfomances as:
#
# Validation accuracy: 0.9641242937853107
# Standard deviation of the validation accuracy: 0.13439946498953412
# 95-percentile of the validation accuracy: 0.26207895672959153

# %%
print(len(svm_total_acc_test))
# Out:
# 205320
